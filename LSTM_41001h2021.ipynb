# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
# Assuming your text file is named "data.txt" and is in the same directory as your Python script
file_path = "/content/41001h2021.txt"

# If your data is separated by spaces, you can use:
df = pd.read_csv(file_path, delim_whitespace=True)

# %%
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD   GST   WVHT    DPD    APD  MWD    PRES  \
# 0  2021   6  20   5  40   216   9.3  11.3   1.42   4.76   4.56  225  1015.6
# 1  2021   6  20   5  50   215   9.1  11.2  99.00  99.00  99.00  999  1015.4
# 2  2021   6  20   6   0   214   8.9  10.8  99.00  99.00  99.00  999  1015.3
# 3  2021   6  20   6  10   215   9.3  11.0  99.00  99.00  99.00  999  1015.3
# 4  2021   6  20   6  20   214   9.0  11.0  99.00  99.00  99.00  999  1015.2
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 0  25.1  25.2  24.1  99.0  99.0
# 1  25.1  25.2  24.1  99.0  99.0
# 2  25.1  25.2  24.1  99.0  99.0
# 3  25.1  25.2  24.2  99.0  99.0
# 4  25.1  25.2  24.2  99.0  99.0

# %%
# Remove the first row
df = df.iloc[1:]
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD   GST  WVHT   DPD   APD  MWD    PRES  \
# 1  2021   6  20   5  50   215   9.1  11.2  99.0  99.0  99.0  999  1015.4
# 2  2021   6  20   6   0   214   8.9  10.8  99.0  99.0  99.0  999  1015.3
# 3  2021   6  20   6  10   215   9.3  11.0  99.0  99.0  99.0  999  1015.3
# 4  2021   6  20   6  20   214   9.0  11.0  99.0  99.0  99.0  999  1015.2
# 5  2021   6  20   6  30   213   8.9  11.2  99.0  99.0  99.0  999  1015.2
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 1  25.1  25.2  24.1  99.0  99.0
# 2  25.1  25.2  24.1  99.0  99.0
# 3  25.1  25.2  24.2  99.0  99.0
# 4  25.1  25.2  24.2  99.0  99.0
# 5  25.1  25.2  24.3  99.0  99.0

# %%
df.shape
# Out:
# (10476, 18)

# %%
# Convert specific columns to numeric values
columns_to_convert = ['#YY', 'MM', 'DD', 'hh', 'mm', 'WDIR', 'WSPD', 'GST', 'WVHT', 'DPD', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP', 'VIS', 'TIDE']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')
# Alternatively, convert all object columns to numeric values
df = df.apply(pd.to_numeric, errors='coerce')

# %%
# Extract rows where mm=0
df = df[df["mm"] == 40]

# %%
#here we reset the index
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (1746, 18)

# %%
df.isnull().sum()
# Out:
# #YY     0
# MM      0
# DD      0
# hh      0
# mm      0
# WDIR    0
# WSPD    0
# GST     0
# WVHT    0
# DPD     0
# APD     0
# MWD     0
# PRES    0
# ATMP    0
# WTMP    0
# DEWP    0
# VIS     0
# TIDE    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1746, 18)

# %%
# Combine date and time columns into a single datetime column
df['date_time'] = pd.to_datetime(df[['#YY', 'MM', 'DD', 'hh', 'mm']].astype(str).apply(' '.join, axis=1), format='%Y %m %d %H %M')

# %%
# Drop 5 columns by specifying their column labels
columns_to_drop = ['#YY', 'MM', 'DD', 'hh', 'mm']
df = df.drop(columns=columns_to_drop)

# %%
#Move the 'date_time' column to the first position
date_time_column = df.pop('date_time')
df.insert(0, 'date_time', date_time_column)

# %%
df.head()
# Out:
#             date_time  WDIR  WSPD   GST  WVHT   DPD   APD  MWD    PRES  ATMP  \
# 0 2021-06-20 06:40:00   214   9.4  11.2  1.34  5.88  4.53  246  1015.1  25.1
# 1 2021-06-20 07:40:00   218   8.8  10.7  1.39  4.76  4.54  221  1015.5  25.2
# 2 2021-06-20 08:40:00   222   8.8  10.6  1.42  4.76  4.57  235  1015.9  25.3
# 3 2021-06-20 09:40:00   224   8.6  10.7  1.42  7.69  4.62  175  1016.2  25.5
# 4 2021-06-20 10:40:00   222   8.9  11.1  1.35  6.67  4.51  243  1016.2  25.6
#
#     WTMP  DEWP   VIS  TIDE
# 0  999.0  24.4  99.0  99.0
# 1   25.2  24.5  99.0  99.0
# 2   25.2  24.8  99.0  99.0
# 3   25.1  24.8  99.0  99.0
# 4   25.1  25.0  99.0  99.0

# %%
df["WVHT"]=df["WVHT"].astype(float)

# %%
# Assuming you have a DataFrame called 'df'
selected_columns = ['date_time' , 'WVHT']  # Specify the columns you want to select

data = df[selected_columns]  # Create a new DataFrame by selecting the specified columns

# Print the new DataFrame
print(data)
# Out:
#                date_time  WVHT
# 0    2021-06-20 06:40:00  1.34
# 1    2021-06-20 07:40:00  1.39
# 2    2021-06-20 08:40:00  1.42
# 3    2021-06-20 09:40:00  1.42
# 4    2021-06-20 10:40:00  1.35
# ...                  ...   ...
# 1741 2021-08-31 19:40:00  1.06
# 1742 2021-08-31 20:40:00  1.02
# 1743 2021-08-31 21:40:00  1.01
# 1744 2021-08-31 22:40:00  0.96
# 1745 2021-08-31 23:40:00  1.02
#
# [1746 rows x 2 columns]

# %%
unique_values = data['WVHT'].unique()
unique_values
# Out:
# array([ 1.34,  1.39,  1.42,  1.35,  1.43,  1.57,  1.6 ,  1.46,  1.41,
#         1.37,  1.38,  1.4 ,  1.48,  1.36,  1.45,  1.33,  1.26,  1.78,
#         1.49,  1.59,  1.76,  2.08,  2.81,  2.93,  3.29,  3.68,  3.36,
#         3.25,  3.  ,  3.15,  2.95,  2.76,  2.77,  2.7 ,  2.67,  2.85,
#         2.54,  2.52,  2.78,  2.57,  2.49,  2.38,  2.4 ,  2.53,  2.3 ,
#         2.2 ,  2.16,  2.31,  2.32,  2.43,  2.39,  2.96,  2.6 ,  2.74,
#         2.28,  2.27,  2.03,  1.92,  1.69,  1.65,  1.58,  1.66,  1.7 ,
#         1.53,  2.02,  2.36,  2.37,  2.23,  2.06,  1.83,  1.51,  1.44,
#         1.32,  1.3 ,  1.28,  1.22,  1.25,  1.19,  1.18,  1.11,  1.12,
#         1.1 ,  1.  ,  1.02,  0.97,  0.95,  0.92,  0.87,  0.9 ,  0.98,
#         1.06,  1.03,  1.05,  1.09,  1.07,  1.04,  0.86,  0.93,  1.08,
#         0.96,  0.94,  1.2 ,  1.23,  1.21,  1.29,  1.5 ,  1.63,  1.56,
#         1.8 ,  1.79,  1.73,  1.75,  1.74,  1.71,  1.82,  1.01,  0.84,
#         0.82,  0.81,  0.85,  0.89,  0.74,  0.83,  0.79,  0.77,  0.76,
#         0.78,  0.8 ,  0.75,  1.15,  1.24,  1.54,  1.64,  1.94,  1.89,
#         1.86,  1.87,  2.1 ,  1.99,  2.19,  1.97,  2.18,  2.33,  2.41,
#         2.65,  2.89,  3.03,  3.01,  3.47,  3.51,  3.19,  3.43,  3.58,
#         3.53,  3.24,  3.26,  3.18,  3.13,  3.05,  2.91,  2.84,  3.07,
#         2.88,  2.87,  2.72,  2.61,  2.5 ,  2.9 ,  2.64,  2.24,  2.12,
#         1.91,  1.84,  1.77,  1.61,  1.81,  1.67,  2.11,  2.13,  2.04,
#         1.96,  1.85,  1.9 ,  1.55,  0.91,  1.14,  2.07,  2.45,  2.14,
#         2.25,  2.29,  2.  ,  1.98,  2.22,  2.05,  1.47,  1.52,  1.31,
#         0.99,  0.88,  0.73, 99.  ,  1.16,  1.17,  2.42,  2.35,  2.44,
#         2.17,  2.51,  1.72,  1.95,  1.27,  1.13,  0.72,  0.7 ,  0.66,
#         0.71,  0.65,  0.64,  0.67,  0.63,  0.62,  1.68,  1.88,  1.62,
#         2.09,  2.15,  2.21,  2.47,  2.56,  2.62,  2.59,  2.98,  2.46,
#         2.26,  2.01,  2.68,  2.83,  2.73,  2.86,  2.82,  2.66,  0.69,
#         0.68,  2.8 ,  2.99,  3.22,  3.84,  3.79,  3.95,  4.26,  4.64,
#         5.07,  5.49,  5.33,  5.15,  4.12,  3.87,  3.67,  3.97,  3.35,
#         3.42,  2.55,  2.63,  1.93,  2.58,  3.2 ,  3.31,  3.52,  3.49,
#         3.17,  3.1 ,  3.08,  3.28,  3.38,  3.48,  3.33])

# %%
data = data[data['WVHT'] != 99]

# %%
data.shape
# Out:
# (1744, 2)

# %%
data['WVHT'].plot(figsize=(8,6))
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data = data.sort_values(by='date_time')
y = data['WVHT'].values

# %%
# Define a function to prepare sequences
def prepare_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

# %%
# Prepare sequences and targets
sequence_length = 100  # Adjust as needed
x_seq, y_targets = prepare_sequences(y, sequence_length)

# %%
# Split the data into train and test sets
split_ratio = 0.7  # Adjust as needed
split_idx = int(split_ratio * len(x_seq))
x_train, x_test = x_seq[:split_idx], x_seq[split_idx:]
y_train, y_test = y_targets[:split_idx], y_targets[split_idx:]

# %%
# Define quantile loss function using TensorFlow operations
def quantile_loss(q, y_true, y_pred):
    error = y_true - y_pred
    return tf.reduce_mean(tf.maximum(q * error, (q - 1) * error))

# %%
# Import the Dropout layer from TensorFlow
from tensorflow.keras.layers import Dropout

# %%
# Define and train the LSTM model with quantile loss
def train_model_with_quantile_loss(q):
    model = Sequential([
        LSTM(64, activation='sigmoid', input_shape=(sequence_length, 1)),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss=lambda y_true, y_pred: quantile_loss(q, y_true, y_pred))
    model.fit(x_train, y_train, validation_split=0.1, epochs=50, batch_size=32, verbose=1)
    return model

# %%
#Train models with 20% and 80% quantiles
q_05 = 0.05  # 10% quantile
model_05 = train_model_with_quantile_loss(q_05)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 3s 46ms/step - loss: 0.0360 - val_loss: 0.0352
# Epoch 2/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0355 - val_loss: 0.0331
# Epoch 3/50
# 33/33 [==============================] - 2s 58ms/step - loss: 0.0314 - val_loss: 0.0219
# Epoch 4/50
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0282 - val_loss: 0.0183
# Epoch 5/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0254 - val_loss: 0.0350
# Epoch 6/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0226 - val_loss: 0.0119
# Epoch 7/50
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0166 - val_loss: 0.0101
# Epoch 8/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0174 - val_loss: 0.0181
# Epoch 9/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0138 - val_loss: 0.0079
# Epoch 10/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0127 - val_loss: 0.0068
# Epoch 11/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0119 - val_loss: 0.0099
# Epoch 12/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0124 - val_loss: 0.0079
# Epoch 13/50
# 33/33 [==============================] - 2s 63ms/step - loss: 0.0124 - val_loss: 0.0065
# Epoch 14/50
# 33/33 [==============================] - 2s 52ms/step - loss: 0.0114 - val_loss: 0.0070
# Epoch 15/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0111 - val_loss: 0.0080
# Epoch 16/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0135 - val_loss: 0.0139
# Epoch 17/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0112 - val_loss: 0.0066
# Epoch 18/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0131 - val_loss: 0.0092
# Epoch 19/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0144 - val_loss: 0.0074
# Epoch 20/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0120 - val_loss: 0.0063
# Epoch 21/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0110 - val_loss: 0.0066
# Epoch 22/50
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0107 - val_loss: 0.0064
# Epoch 23/50
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0118 - val_loss: 0.0070
# Epoch 24/50
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0104 - val_loss: 0.0062
# Epoch 25/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0104 - val_loss: 0.0072
# Epoch 26/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0106 - val_loss: 0.0097
# Epoch 27/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0107 - val_loss: 0.0064
# Epoch 28/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0107 - val_loss: 0.0074
# Epoch 29/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0110 - val_loss: 0.0060
# Epoch 30/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0105 - val_loss: 0.0067
# Epoch 31/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0104 - val_loss: 0.0088
# Epoch 32/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0112 - val_loss: 0.0076
# Epoch 33/50
# 33/33 [==============================] - 2s 70ms/step - loss: 0.0114 - val_loss: 0.0061
# Epoch 34/50
# 33/33 [==============================] - 2s 69ms/step - loss: 0.0105 - val_loss: 0.0063
# Epoch 35/50
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0102 - val_loss: 0.0196
# Epoch 36/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0113 - val_loss: 0.0088
# Epoch 37/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0104 - val_loss: 0.0064
# Epoch 38/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0115 - val_loss: 0.0062
# Epoch 39/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0107 - val_loss: 0.0060
# Epoch 40/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0104 - val_loss: 0.0063
# Epoch 41/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0110 - val_loss: 0.0081
# Epoch 42/50
# 33/33 [==============================] - 2s 62ms/step - loss: 0.0111 - val_loss: 0.0179
# Epoch 43/50
# 33/33 [==============================] - 2s 51ms/step - loss: 0.0128 - val_loss: 0.0065
# Epoch 44/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0107 - val_loss: 0.0058
# Epoch 45/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0101 - val_loss: 0.0057
# Epoch 46/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0106 - val_loss: 0.0059
# Epoch 47/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0100 - val_loss: 0.0075
# Epoch 48/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0111 - val_loss: 0.0064
# Epoch 49/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0102 - val_loss: 0.0085
# Epoch 50/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0106 - val_loss: 0.0096

# %%
q_95 = 0.95  # 90% quantile
model_95 = train_model_with_quantile_loss(q_95)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 4s 66ms/step - loss: 0.7053 - val_loss: 0.0565
# Epoch 2/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0754 - val_loss: 0.0805
# Epoch 3/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0733 - val_loss: 0.0764
# Epoch 4/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0725 - val_loss: 0.0735
# Epoch 5/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0717 - val_loss: 0.0719
# Epoch 6/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0708 - val_loss: 0.0718
# Epoch 7/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0698 - val_loss: 0.0722
# Epoch 8/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0687 - val_loss: 0.0685
# Epoch 9/50
# 33/33 [==============================] - 1s 43ms/step - loss: 0.0676 - val_loss: 0.0660
# Epoch 10/50
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0654 - val_loss: 0.0657
# Epoch 11/50
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0636 - val_loss: 0.0640
# Epoch 12/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0619 - val_loss: 0.0616
# Epoch 13/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0601 - val_loss: 0.0626
# Epoch 14/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0571 - val_loss: 0.0537
# Epoch 15/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0561 - val_loss: 0.0543
# Epoch 16/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0524 - val_loss: 0.0554
# Epoch 17/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0498 - val_loss: 0.0494
# Epoch 18/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0468 - val_loss: 0.0453
# Epoch 19/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0434 - val_loss: 0.0359
# Epoch 20/50
# 33/33 [==============================] - 2s 64ms/step - loss: 0.0406 - val_loss: 0.0386
# Epoch 21/50
# 33/33 [==============================] - 1s 39ms/step - loss: 0.0364 - val_loss: 0.0271
# Epoch 22/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0316 - val_loss: 0.0233
# Epoch 23/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0259 - val_loss: 0.0195
# Epoch 24/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0222 - val_loss: 0.0146
# Epoch 25/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0195 - val_loss: 0.0132
# Epoch 26/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0199 - val_loss: 0.0136
# Epoch 27/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0200 - val_loss: 0.0118
# Epoch 28/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0185 - val_loss: 0.0137
# Epoch 29/50
# 33/33 [==============================] - 2s 56ms/step - loss: 0.0170 - val_loss: 0.0110
# Epoch 30/50
# 33/33 [==============================] - 2s 61ms/step - loss: 0.0163 - val_loss: 0.0117
# Epoch 31/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0159 - val_loss: 0.0110
# Epoch 32/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0164 - val_loss: 0.0102
# Epoch 33/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0156 - val_loss: 0.0107
# Epoch 34/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0153 - val_loss: 0.0185
# Epoch 35/50
# 33/33 [==============================] - 1s 36ms/step - loss: 0.0171 - val_loss: 0.0130
# Epoch 36/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0148 - val_loss: 0.0113
# Epoch 37/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0148 - val_loss: 0.0195
# Epoch 38/50
# 33/33 [==============================] - 1s 38ms/step - loss: 0.0154 - val_loss: 0.0129
# Epoch 39/50
# 33/33 [==============================] - 2s 69ms/step - loss: 0.0142 - val_loss: 0.0141
# Epoch 40/50
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0138 - val_loss: 0.0093
# Epoch 41/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0137 - val_loss: 0.0090
# Epoch 42/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0141 - val_loss: 0.0168
# Epoch 43/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0172 - val_loss: 0.0089
# Epoch 44/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0140 - val_loss: 0.0160
# Epoch 45/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0143 - val_loss: 0.0100
# Epoch 46/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 47/50
# 33/33 [==============================] - 1s 37ms/step - loss: 0.0142 - val_loss: 0.0086
# Epoch 48/50
# 33/33 [==============================] - 2s 46ms/step - loss: 0.0132 - val_loss: 0.0090
# Epoch 49/50
# 33/33 [==============================] - 2s 66ms/step - loss: 0.0146 - val_loss: 0.0093
# Epoch 50/50
# 33/33 [==============================] - 1s 41ms/step - loss: 0.0130 - val_loss: 0.0096

# %%
# Make predictions
y_pred_05 = model_05.predict(x_test)
y_pred_95 = model_95.predict(x_test)
# Out:
# 16/16 [==============================] - 0s 15ms/step
# 16/16 [==============================] - 0s 15ms/step

# %%
# Plot quantile predictions along with actual values
plt.plot(range(len(y_test)), y_test, label="Actual")
plt.plot(range(len(y_test)), y_pred_05, label="5% Prediction")
plt.plot(range(len(y_test)), y_pred_95, label="95% Prediction")
plt.xlabel("Data Points in Test Set")
plt.ylabel("WVHT")
plt.legend()
plt.savefig('41001h2021.png')
plt.show()

# Calculate the number of points between 95% and 5% percentiles
num_points_between_percentiles = np.sum((y_pred_05 <= y_test) & (y_test <= y_pred_95))

# %%
# Calculate MPIW
def calculate_mpiw(y_lower, y_upper):
    mpiw = np.mean(y_upper - y_lower)
    return mpiw

# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Calculate MPIW for the 10-90% prediction interval
mpiw = calculate_mpiw(y_lower_05, y_upper_95)

# Print MPIW for the 10-90% prediction interval
print("MPIW:", mpiw)
# Out:
# MPIW: 0.4179913

# %%
print(len(y_test))
# Out:
# 494

# %%
# Check if each actual observation falls within the prediction interval
within_interval = (y_pred_05.flatten() <= y_test) & (y_test <= y_pred_95.flatten())
print(within_interval.sum())
# Out:
# 466

# %%
# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Check if each actual observation falls within the prediction interval
within_interval = (y_lower_05.flatten() <= y_test) & (y_test <= y_upper_95.flatten())

# Count the number of observations falling within the prediction intervals
num_within_interval = within_interval.sum()

# Total number of observations
total_observations = len(y_test)

# Calculate PICP (Prediction Interval Coverage Probability)
picp = num_within_interval / total_observations
print("PICP:", picp)
# Out:
# PICP: 0.9433198380566802
