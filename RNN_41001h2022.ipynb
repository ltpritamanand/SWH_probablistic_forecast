# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
# Assuming your text file is named "data.txt" and is in the same directory as your Python script
file_path = "/content/41001h2022 (2).txt"

# If your data is separated by spaces, you can use:
df = pd.read_csv(file_path, delim_whitespace=True)

# %%
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD   GST   WVHT    DPD    APD  MWD    PRES  \
# 0  2022   3   2  20  40   234   8.3  10.8   1.31   7.69   5.45  113  1017.5
# 1  2022   3   2  20  50   233   8.4  11.0  99.00  99.00  99.00  999  1017.4
# 2  2022   3   2  21   0   231   8.8  11.6  99.00  99.00  99.00  999  1017.5
# 3  2022   3   2  21  10   238   8.8  11.3  99.00  99.00  99.00  999  1017.5
# 4  2022   3   2  21  20   236   8.4  10.7  99.00  99.00  99.00  999  1017.5
#
#    ATMP  WTMP   DEWP   VIS  TIDE
# 0  19.5  20.2  999.0  99.0  99.0
# 1  19.6  20.1  999.0  99.0  99.0
# 2  19.6  20.0  999.0  99.0  99.0
# 3  19.6  20.0  999.0  99.0  99.0
# 4  19.7  19.9  999.0  99.0  99.0

# %%
# Remove the first row
df = df.iloc[1:]
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD   GST  WVHT   DPD   APD  MWD    PRES  \
# 1  2022   3   2  20  50   233   8.4  11.0  99.0  99.0  99.0  999  1017.4
# 2  2022   3   2  21   0   231   8.8  11.6  99.0  99.0  99.0  999  1017.5
# 3  2022   3   2  21  10   238   8.8  11.3  99.0  99.0  99.0  999  1017.5
# 4  2022   3   2  21  20   236   8.4  10.7  99.0  99.0  99.0  999  1017.5
# 5  2022   3   2  21  30   239   8.7  11.4  99.0  99.0  99.0  999  1017.5
#
#    ATMP  WTMP   DEWP   VIS  TIDE
# 1  19.6  20.1  999.0  99.0  99.0
# 2  19.6  20.0  999.0  99.0  99.0
# 3  19.6  20.0  999.0  99.0  99.0
# 4  19.7  19.9  999.0  99.0  99.0
# 5  19.7  19.8  999.0  99.0  99.0

# %%
df.shape
# Out:
# (12962, 18)

# %%
# Convert specific columns to numeric values
columns_to_convert = ['#YY', 'MM', 'DD', 'hh', 'mm', 'WDIR', 'WSPD', 'GST', 'WVHT', 'DPD', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP', 'VIS', 'TIDE']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')
# Alternatively, convert all object columns to numeric values
df = df.apply(pd.to_numeric, errors='coerce')

# %%
# Extract rows where mm=0
df = df[df["mm"] == 40]

# %%
#here we reset the index
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (2162, 18)

# %%
df.isnull().sum()
# Out:
# #YY     0
# MM      0
# DD      0
# hh      0
# mm      0
# WDIR    0
# WSPD    0
# GST     0
# WVHT    0
# DPD     0
# APD     0
# MWD     0
# PRES    0
# ATMP    0
# WTMP    0
# DEWP    0
# VIS     0
# TIDE    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (2162, 18)

# %%
# Combine date and time columns into a single datetime column
df['date_time'] = pd.to_datetime(df[['#YY', 'MM', 'DD', 'hh', 'mm']].astype(str).apply(' '.join, axis=1), format='%Y %m %d %H %M')

# %%
# Drop 5 columns by specifying their column labels
columns_to_drop = ['#YY', 'MM', 'DD', 'hh', 'mm']
df = df.drop(columns=columns_to_drop)

# %%
#Move the 'date_time' column to the first position
date_time_column = df.pop('date_time')
df.insert(0, 'date_time', date_time_column)

# %%
df.head()
# Out:
#             date_time  WDIR  WSPD   GST  WVHT   DPD   APD  MWD    PRES  ATMP  \
# 0 2022-03-02 21:40:00   236   9.3  11.5  1.46  5.56  5.40  214  1017.7  19.7
# 1 2022-03-02 22:40:00   235   7.7   9.6  1.63  5.88  5.50  219  1018.0  19.6
# 2 2022-03-02 23:40:00   230   7.3  10.7  1.40  5.88  5.49  229  1018.3  19.2
# 3 2022-03-03 00:40:00   209   4.9   6.5  1.32  5.26  5.45  244  1018.7  18.4
# 4 2022-03-03 01:40:00   226   6.8  10.2  1.31  5.00  5.49  281  1018.6  19.5
#
#    WTMP   DEWP   VIS  TIDE
# 0  19.8  999.0  99.0  99.0
# 1  20.0  999.0  99.0  99.0
# 2  19.9  999.0  99.0  99.0
# 3  19.8  999.0  99.0  99.0
# 4  19.9  999.0  99.0  99.0

# %%
df["WVHT"]=df["WVHT"].astype(float)

# %%
# Assuming you have a DataFrame called 'df'
selected_columns = ['date_time' , 'WVHT']  # Specify the columns you want to select

data = df[selected_columns]  # Create a new DataFrame by selecting the specified columns

# Print the new DataFrame
print(data)
# Out:
#                date_time  WVHT
# 0    2022-03-02 21:40:00  1.46
# 1    2022-03-02 22:40:00  1.63
# 2    2022-03-02 23:40:00  1.40
# 3    2022-03-03 00:40:00  1.32
# 4    2022-03-03 01:40:00  1.31
# ...                  ...   ...
# 2157 2022-05-31 19:40:00  0.54
# 2158 2022-05-31 20:40:00  0.52
# 2159 2022-05-31 21:40:00  0.53
# 2160 2022-05-31 22:40:00  0.53
# 2161 2022-05-31 23:40:00  0.53
#
# [2162 rows x 2 columns]

# %%
unique_values = data['WVHT'].unique()
unique_values
# Out:
# array([ 1.46,  1.63,  1.4 ,  1.32,  1.31,  1.49,  1.53,  1.69,  1.76,
#         1.73,  1.7 ,  1.55,  1.54,  1.27,  1.41,  1.58,  1.5 ,  1.64,
#         1.68,  1.57,  1.44,  1.85,  2.06,  2.19,  2.1 ,  2.3 ,  2.34,
#         2.26,  2.18,  2.16,  1.88,  1.62,  1.74,  1.87,  1.71,  1.65,
#         1.66,  1.61,  1.43,  1.42,  1.36,  1.34,  1.3 ,  1.24,  1.2 ,
#         1.12,  1.22,  1.04,  1.03,  1.05,  1.06,  1.16,  1.13,  1.19,
#         1.18,  1.23,  1.25,  1.26,  1.21,  1.33,  1.35,  1.51,  1.67,
#         1.79,  1.91,  1.75,  2.  ,  2.14,  2.23,  2.72,  2.83,  2.91,
#         2.81,  3.25,  3.14,  3.01,  2.93,  3.07,  3.03,  2.56,  2.68,
#         2.9 ,  2.47,  2.39,  2.36,  2.17,  2.28,  2.38,  2.71,  2.58,
#         2.31,  2.24,  2.05,  2.11,  2.13,  1.96,  1.93, 99.  ,  1.94,
#         2.08,  2.62,  2.94,  2.98,  3.04,  3.2 ,  3.23,  3.05,  3.06,
#         2.95,  2.84,  2.92,  2.41,  2.29,  1.95,  2.02,  2.03,  1.98,
#         1.8 ,  1.86,  1.52,  1.47,  1.45,  1.37,  2.01,  2.33,  2.97,
#         3.31,  3.36,  3.62,  4.24,  4.71,  5.06,  5.48,  5.86,  6.74,
#         6.95,  6.23,  6.1 ,  6.66,  6.09,  6.17,  6.88,  7.44,  7.24,
#         7.34,  7.28,  7.55,  6.54,  6.37,  6.94,  5.93,  6.19,  5.49,
#         5.3 ,  5.2 ,  5.11,  4.3 ,  3.72,  3.93,  3.26,  3.22,  3.11,
#         2.73,  1.89,  1.29,  1.08,  0.99,  0.97,  0.91,  0.96,  0.9 ,
#         0.83,  0.75,  0.84,  0.76,  0.78,  0.86,  0.82,  0.81,  0.74,
#         0.77,  0.8 ,  0.85,  0.71,  0.94,  0.87,  0.88,  0.92,  0.95,
#         1.39,  1.56,  1.72,  2.04,  1.81,  2.22,  2.07,  2.2 ,  2.55,
#         2.52,  2.44,  2.65,  2.89,  2.82,  3.46,  2.88,  2.79,  2.51,
#         2.37,  2.53,  2.4 ,  1.92,  1.82,  1.6 ,  1.48,  1.78,  2.32,
#         2.54,  2.64,  2.6 ,  2.8 ,  2.61,  2.66,  2.75,  2.48,  2.49,
#         3.24,  3.95,  4.23,  4.44,  4.13,  3.6 ,  3.64,  3.53,  3.17,
#         2.87,  2.57,  2.59,  2.45,  2.27,  1.83,  1.02,  1.09,  1.14,
#         1.  ,  1.17,  1.11,  1.1 ,  1.07,  1.99,  2.21,  2.15,  2.85,
#         3.12,  2.74,  2.99,  3.13,  3.19,  3.48,  3.56,  3.28,  3.09,
#         2.46,  2.76,  3.  ,  3.45,  3.34,  3.15,  3.57,  3.18,  3.51,
#         2.67,  2.7 ,  2.86,  3.32,  2.63,  2.77,  3.39,  3.52,  3.47,
#         3.49,  3.21,  2.69,  2.25,  2.43,  1.77,  1.15,  1.38,  2.35,
#         3.1 ,  3.37,  3.66,  3.84,  4.16,  3.43,  4.15,  4.93,  4.61,
#         4.53,  4.64,  4.01,  4.18,  4.29,  3.99,  3.35,  3.71,  3.33,
#         3.3 ,  3.08,  2.42,  0.98,  3.38,  3.75,  3.4 ,  3.69,  3.42,
#         3.59,  2.78,  3.02,  3.68,  4.06,  4.04,  4.38,  4.6 ,  4.36,
#         4.57,  4.89,  4.83,  4.46,  4.02,  3.63,  3.41,  3.16,  1.59,
#         1.97,  1.84,  1.28,  2.09,  2.12,  1.01,  0.93,  0.79,  2.5 ,
#         1.9 ,  3.97,  4.2 ,  3.7 ,  4.08,  3.86,  3.83,  3.88,  3.87,
#         4.11,  3.89,  3.77,  4.37,  4.21,  5.03,  4.82,  4.74,  5.25,
#         5.17,  4.87,  4.75,  4.59,  4.27,  4.05,  3.98,  3.74,  3.65,
#         3.44,  2.96,  3.54,  3.61,  3.67,  3.27,  0.89,  0.73,  0.65,
#         0.67,  0.69,  0.62,  0.61,  0.6 ,  0.58,  0.59,  0.55,  0.54,
#         0.56,  0.53,  0.51,  0.52])

# %%
data = data[data['WVHT'] != 99]

# %%
data.shape
# Out:
# (2156, 2)

# %%
data['WVHT'].plot(figsize=(8,6))
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data = data.sort_values(by='date_time')
y = data['WVHT'].values

# %%
# Define a function to prepare sequences
def prepare_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

# %%
# Prepare sequences and targets
sequence_length = 100  # Adjust as needed
x_seq, y_targets = prepare_sequences(y, sequence_length)

# %%
# Split the data into train and test sets
split_ratio = 0.7  # Adjust as needed
split_idx = int(split_ratio * len(x_seq))
x_train, x_test = x_seq[:split_idx], x_seq[split_idx:]
y_train, y_test = y_targets[:split_idx], y_targets[split_idx:]

# %%
# Define quantile loss function using TensorFlow operations
def quantile_loss(q, y_true, y_pred):
    error = y_true - y_pred
    return tf.reduce_mean(tf.maximum(q * error, (q - 1) * error))

# %%
# Import the Dropout layer from TensorFlow
from tensorflow.keras.layers import Dropout

# %%
from tensorflow.keras.layers import SimpleRNN

# Define and train the RNN model with quantile loss
def train_model_with_quantile_loss(q):
    model = Sequential([
        SimpleRNN(64, activation='relu', input_shape=(sequence_length, 1)),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss=lambda y_true, y_pred: quantile_loss(q, y_true, y_pred))
    model.fit(x_train, y_train, validation_split=0.1, epochs=50, batch_size=32, verbose=1)
    return model

# %%
#Train models with 20% and 80% quantiles
q_05 = 0.05  # 10% quantile
model_05 = train_model_with_quantile_loss(q_05)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 3s 38ms/step - loss: 0.0515 - val_loss: 0.0090
# Epoch 2/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0178 - val_loss: 0.0115
# Epoch 3/50
# 41/41 [==============================] - 1s 21ms/step - loss: 0.0175 - val_loss: 0.0115
# Epoch 4/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0173 - val_loss: 0.0126
# Epoch 5/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0176 - val_loss: 0.0107
# Epoch 6/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0178 - val_loss: 0.0115
# Epoch 7/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0173 - val_loss: 0.0115
# Epoch 8/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0174 - val_loss: 0.0103
# Epoch 9/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0164 - val_loss: 0.0135
# Epoch 10/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0182 - val_loss: 0.0104
# Epoch 11/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0169 - val_loss: 0.0121
# Epoch 12/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0174 - val_loss: 0.0103
# Epoch 13/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0163 - val_loss: 0.0099
# Epoch 14/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0168 - val_loss: 0.0100
# Epoch 15/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0165 - val_loss: 0.0104
# Epoch 16/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0166 - val_loss: 0.0104
# Epoch 17/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0160 - val_loss: 0.0098
# Epoch 18/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0162 - val_loss: 0.0096
# Epoch 19/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0163 - val_loss: 0.0092
# Epoch 20/50
# 41/41 [==============================] - 1s 30ms/step - loss: 0.0163 - val_loss: 0.0090
# Epoch 21/50
# 41/41 [==============================] - 1s 21ms/step - loss: 0.0175 - val_loss: 0.0139
# Epoch 22/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0174 - val_loss: 0.0110
# Epoch 23/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0161 - val_loss: 0.0100
# Epoch 24/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0166 - val_loss: 0.0096
# Epoch 25/50
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0171 - val_loss: 0.0107
# Epoch 26/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0160 - val_loss: 0.0117
# Epoch 27/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0185 - val_loss: 0.0095
# Epoch 28/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0163 - val_loss: 0.0096
# Epoch 29/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0160 - val_loss: 0.0092
# Epoch 30/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0158 - val_loss: 0.0097
# Epoch 31/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0171 - val_loss: 0.0139
# Epoch 32/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0180 - val_loss: 0.0103
# Epoch 33/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0163 - val_loss: 0.0094
# Epoch 34/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0162 - val_loss: 0.0104
# Epoch 35/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0166 - val_loss: 0.0108
# Epoch 36/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0160 - val_loss: 0.0094
# Epoch 37/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0160 - val_loss: 0.0090
# Epoch 38/50
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0164 - val_loss: 0.0091
# Epoch 39/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0165 - val_loss: 0.0091
# Epoch 40/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0158 - val_loss: 0.0098
# Epoch 41/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0164 - val_loss: 0.0095
# Epoch 42/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0159 - val_loss: 0.0096
# Epoch 43/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0165 - val_loss: 0.0093
# Epoch 44/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0160 - val_loss: 0.0101
# Epoch 45/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0165 - val_loss: 0.0095
# Epoch 46/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0161 - val_loss: 0.0097
# Epoch 47/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0162 - val_loss: 0.0101
# Epoch 48/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0161 - val_loss: 0.0097
# Epoch 49/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0166 - val_loss: 0.0101
# Epoch 50/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0158 - val_loss: 0.0100

# %%
q_95 = 0.95  # 90% quantile
model_95 = train_model_with_quantile_loss(q_95)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 2s 27ms/step - loss: 0.7714 - val_loss: 0.0203
# Epoch 2/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0357 - val_loss: 0.0213
# Epoch 3/50
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0264 - val_loss: 0.0165
# Epoch 4/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0275 - val_loss: 0.0138
# Epoch 5/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0248 - val_loss: 0.0159
# Epoch 6/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0234 - val_loss: 0.0119
# Epoch 7/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0237 - val_loss: 0.0139
# Epoch 8/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0220 - val_loss: 0.0150
# Epoch 9/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0220 - val_loss: 0.0117
# Epoch 10/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0218 - val_loss: 0.0145
# Epoch 11/50
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0212 - val_loss: 0.0127
# Epoch 12/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0227 - val_loss: 0.0176
# Epoch 13/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0217 - val_loss: 0.0163
# Epoch 14/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0227 - val_loss: 0.0125
# Epoch 15/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0207 - val_loss: 0.0127
# Epoch 16/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0207 - val_loss: 0.0149
# Epoch 17/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0211 - val_loss: 0.0128
# Epoch 18/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0210 - val_loss: 0.0179
# Epoch 19/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.0214 - val_loss: 0.0164
# Epoch 20/50
# 41/41 [==============================] - 1s 27ms/step - loss: 0.0205 - val_loss: 0.0158
# Epoch 21/50
# 41/41 [==============================] - 1s 29ms/step - loss: 0.0203 - val_loss: 0.0139
# Epoch 22/50
# 41/41 [==============================] - 1s 25ms/step - loss: 0.0194 - val_loss: 0.0113
# Epoch 23/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0202 - val_loss: 0.0122
# Epoch 24/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0202 - val_loss: 0.0146
# Epoch 25/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0194 - val_loss: 0.0126
# Epoch 26/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0208 - val_loss: 0.0146
# Epoch 27/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0200 - val_loss: 0.0130
# Epoch 28/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0199 - val_loss: 0.0163
# Epoch 29/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0208 - val_loss: 0.0212
# Epoch 30/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0221 - val_loss: 0.0154
# Epoch 31/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0191 - val_loss: 0.0123
# Epoch 32/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0191 - val_loss: 0.0121
# Epoch 33/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0192 - val_loss: 0.0149
# Epoch 34/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0199 - val_loss: 0.0127
# Epoch 35/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0195 - val_loss: 0.0105
# Epoch 36/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0203 - val_loss: 0.0124
# Epoch 37/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0191 - val_loss: 0.0109
# Epoch 38/50
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0189 - val_loss: 0.0127
# Epoch 39/50
# 41/41 [==============================] - 1s 30ms/step - loss: 0.0205 - val_loss: 0.0149
# Epoch 40/50
# 41/41 [==============================] - 1s 18ms/step - loss: 0.0193 - val_loss: 0.0133
# Epoch 41/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0186 - val_loss: 0.0113
# Epoch 42/50
# 41/41 [==============================] - 1s 23ms/step - loss: 0.0186 - val_loss: 0.0109
# Epoch 43/50
# 41/41 [==============================] - 1s 28ms/step - loss: 0.0189 - val_loss: 0.0140
# Epoch 44/50
# 41/41 [==============================] - 1s 30ms/step - loss: 0.0186 - val_loss: 0.0112
# Epoch 45/50
# 41/41 [==============================] - 1s 24ms/step - loss: 0.0190 - val_loss: 0.0144
# Epoch 46/50
# 41/41 [==============================] - 1s 16ms/step - loss: 0.0190 - val_loss: 0.0127
# Epoch 47/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0186 - val_loss: 0.0124
# Epoch 48/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0189 - val_loss: 0.0129
# Epoch 49/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0199 - val_loss: 0.0188
# Epoch 50/50
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0205 - val_loss: 0.0119

# %%
# Make predictions
y_pred_05 = model_05.predict(x_test)
y_pred_95 = model_95.predict(x_test)
# Out:
# 20/20 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 8ms/step

# %%
# Plot quantile predictions along with actual values
plt.plot(range(len(y_test)), y_test, label="Actual")
plt.plot(range(len(y_test)), y_pred_05, label="5% Prediction")
plt.plot(range(len(y_test)), y_pred_95, label="95% Prediction")
plt.xlabel("Data Points in Test Set")
plt.ylabel("WVHT")
plt.legend()
plt.savefig("41001h2022.png")

plt.show()

# Calculate the number of points between 95% and 5% percentiles
num_points_between_percentiles = np.sum((y_pred_05 <= y_test) & (y_test <= y_pred_95))

# %%
# Calculate MPIW
def calculate_mpiw(y_lower, y_upper):
    mpiw = np.mean(y_upper - y_lower)
    return mpiw

# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Calculate MPIW for the 10-90% prediction interval
mpiw = calculate_mpiw(y_lower_05, y_upper_95)

# Print MPIW for the 10-90% prediction interval
print("MPIW:", mpiw)
# Out:
# MPIW: 0.42374924

# %%
print(len(y_test))
# Out:
# 617

# %%
within_interval = (y_lower_05.flatten() <= y_test) & (y_test <= y_upper_95.flatten())
print(within_interval.sum())
# Out:
# 588

# %%
# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Check if each actual observation falls within the prediction interval
within_interval = (y_lower_05.flatten() <= y_test) & (y_test <= y_upper_95.flatten())

# Count the number of observations falling within the prediction intervals
num_within_interval = within_interval.sum()

# Total number of observations
total_observations = len(y_test)

# Calculate PICP (Prediction Interval Coverage Probability)
picp = num_within_interval / total_observations
print("PICP:", picp)
# Out:
# PICP: 0.9529983792544571
