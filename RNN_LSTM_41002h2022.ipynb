# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
# Assuming your text file is named "data.txt" and is in the same directory as your Python script
file_path = "/content/41002h2022 (1).txt"

# If your data is separated by spaces, you can use:
df = pd.read_csv(file_path, delim_whitespace=True)

# %%
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD    APD  MWD    PRES  \
# 0  2022   1   1   0   0   304   1.7  3.0  99.00  99.00  99.00  999  1016.9
# 1  2022   1   1   0  10   289   2.0  2.8  99.00  99.00  99.00  999  1017.1
# 2  2022   1   1   0  20   292   2.5  3.7  99.00  99.00  99.00  999  1017.2
# 3  2022   1   1   0  30   285   1.8  3.1  99.00  99.00  99.00  999  1017.3
# 4  2022   1   1   0  40   292   1.8  3.0   1.73   7.14   6.05  270  1017.5
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 0  23.4  24.1  20.3  99.0  99.0
# 1  23.4  24.1  20.4  99.0  99.0
# 2  23.4  24.2  20.4  99.0  99.0
# 3  23.4  24.2  20.5  99.0  99.0
# 4  23.4  24.2  20.5  99.0  99.0

# %%
# Remove the first row
df = df.iloc[1:]
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD    APD  MWD    PRES  \
# 1  2022   1   1   0  10   289   2.0  2.8  99.00  99.00  99.00  999  1017.1
# 2  2022   1   1   0  20   292   2.5  3.7  99.00  99.00  99.00  999  1017.2
# 3  2022   1   1   0  30   285   1.8  3.1  99.00  99.00  99.00  999  1017.3
# 4  2022   1   1   0  40   292   1.8  3.0   1.73   7.14   6.05  270  1017.5
# 5  2022   1   1   0  50   289   2.0  3.0  99.00  99.00  99.00  999  1017.6
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 1  23.4  24.1  20.4  99.0  99.0
# 2  23.4  24.2  20.4  99.0  99.0
# 3  23.4  24.2  20.5  99.0  99.0
# 4  23.4  24.2  20.5  99.0  99.0
# 5  23.3  24.2  20.2  99.0  99.0

# %%
df.shape
# Out:
# (12948, 18)

# %%
# Convert specific columns to numeric values
columns_to_convert = ['#YY', 'MM', 'DD', 'hh', 'mm', 'WDIR', 'WSPD', 'GST', 'WVHT', 'DPD', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP', 'VIS', 'TIDE']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')
# Alternatively, convert all object columns to numeric values
df = df.apply(pd.to_numeric, errors='coerce')

# %%
# Extract rows where mm=0
df = df[df["mm"] == 40]

# %%
#here we reset the index
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (2159, 18)

# %%
df.isnull().sum()
# Out:
# #YY     0
# MM      0
# DD      0
# hh      0
# mm      0
# WDIR    0
# WSPD    0
# GST     0
# WVHT    0
# DPD     0
# APD     0
# MWD     0
# PRES    0
# ATMP    0
# WTMP    0
# DEWP    0
# VIS     0
# TIDE    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (2159, 18)

# %%
# Combine date and time columns into a single datetime column
df['date_time'] = pd.to_datetime(df[['#YY', 'MM', 'DD', 'hh', 'mm']].astype(str).apply(' '.join, axis=1), format='%Y %m %d %H %M')

# %%
# Drop 5 columns by specifying their column labels
columns_to_drop = ['#YY', 'MM', 'DD', 'hh', 'mm']
df = df.drop(columns=columns_to_drop)

# %%
#Move the 'date_time' column to the first position
date_time_column = df.pop('date_time')
df.insert(0, 'date_time', date_time_column)

# %%
df.head()
# Out:
#             date_time  WDIR  WSPD  GST  WVHT   DPD   APD  MWD    PRES  ATMP  \
# 0 2022-01-01 00:40:00   292   1.8  3.0  1.73  7.14  6.05  270  1017.5  23.4
# 1 2022-01-01 01:40:00   238   1.6  2.5  1.58  7.14  5.76  259  1017.6  23.3
# 2 2022-01-01 02:40:00   250   2.5  3.6  1.68  7.14  6.13  269  1017.7  23.3
# 3 2022-01-01 03:40:00   238   3.5  4.6  1.52  6.67  5.82  268  1017.6  23.4
# 4 2022-01-01 04:40:00   230   4.9  6.1  1.50  7.14  6.02  254  1017.1  23.3
#
#    WTMP  DEWP   VIS  TIDE
# 0  24.2  20.5  99.0  99.0
# 1  24.3  20.5  99.0  99.0
# 2  24.3  20.9  99.0  99.0
# 3  24.3  20.6  99.0  99.0
# 4  24.3  20.7  99.0  99.0

# %%
df["WVHT"]=df["WVHT"].astype(float)

# %%
# Assuming you have a DataFrame called 'df'
selected_columns = ['date_time' , 'WVHT']  # Specify the columns you want to select

data = df[selected_columns]  # Create a new DataFrame by selecting the specified columns

# Print the new DataFrame
print(data)
# Out:
#                date_time  WVHT
# 0    2022-01-01 00:40:00  1.73
# 1    2022-01-01 01:40:00  1.58
# 2    2022-01-01 02:40:00  1.68
# 3    2022-01-01 03:40:00  1.52
# 4    2022-01-01 04:40:00  1.50
# ...                  ...   ...
# 2154 2022-03-31 19:40:00  2.10
# 2155 2022-03-31 20:40:00  2.26
# 2156 2022-03-31 21:40:00  2.45
# 2157 2022-03-31 22:40:00  2.32
# 2158 2022-03-31 23:40:00  2.11
#
# [2159 rows x 2 columns]

# %%
unique_values = data['WVHT'].unique()
unique_values
# Out:
# array([ 1.73,  1.58,  1.68,  1.52,  1.5 ,  1.29,  1.26,  1.2 ,  1.05,
#         1.02,  1.  ,  1.01,  0.96,  1.04,  1.13,  1.18,  1.24,  1.31,
#         1.33,  1.35,  1.49,  1.4 ,  1.51,  1.43,  1.48,  1.65,  1.85,
#         1.91,  2.01,  2.1 ,  2.17,  2.04,  2.27,  2.15,  2.31,  2.21,
#         2.14,  2.35,  2.28,  2.2 ,  2.22,  2.3 ,  2.11,  1.98,  2.13,
#         2.25,  2.34,  2.45,  2.43,  2.65,  2.44,  3.16,  3.27,  3.37,
#         3.53,  3.77,  3.96,  4.77,  5.17,  4.9 ,  5.28,  5.33,  6.19,
#         5.13,  4.85,  4.87,  4.13,  3.78,  4.01,  3.82,  3.89,  3.26,
#         4.08,  4.17,  4.19,  3.95,  3.91,  3.9 ,  3.75,  3.83,  3.74,
#         4.09,  4.31,  4.37,  4.49,  4.53,  4.67,  5.34,  4.51,  4.54,
#         3.71,  3.7 ,  3.55,  2.86,  2.92,  2.74,  2.64,  2.76,  2.62,
#         2.52,  2.69,  2.78,  2.49,  2.33,  2.18,  2.03,  2.02,  1.89,
#         1.75,  1.77,  1.69,  1.6 ,  1.55,  1.57,  1.74,  1.93,  1.94,
#         2.12,  2.26,  2.32,  2.38,  2.55,  2.6 ,  2.42,  2.36,  2.81,
#         2.91,  3.31,  3.41,  4.33,  4.18,  4.32,  3.67,  3.54,  3.33,
#         3.08,  2.46,  2.39,  2.47,  2.16,  2.06,  1.87,  1.82,  1.92,
#         1.7 ,  1.8 ,  1.79,  1.81,  1.66,  1.56,  1.53,  1.47,  1.45,
#         1.34,  1.38,  1.23,  1.08,  1.06,  0.93,  0.98,  0.94,  0.99,
#         0.92,  0.95,  1.03,  0.97,  1.07,  1.1 ,  1.22,  1.36,  1.63,
#         1.88,  1.71,  1.97,  2.05,  1.99,  2.4 ,  3.01,  3.3 ,  3.36,
#         3.09,  2.68,  2.72,  2.54,  2.56,  2.73,  2.48,  1.95,  2.09,
#         2.07,  1.67,  1.62,  1.42,  1.41,  1.28,  1.25,  1.17,  1.19,
#         1.3 ,  1.16,  1.09,  1.11,  2.61,  2.9 ,  2.99,  3.05,  2.97,
#         3.6 ,  3.92,  4.39,  3.8 ,  3.72,  3.47,  3.65,  3.87,  3.88,
#         4.21,  4.07,  4.02,  3.64,  3.52,  3.97,  3.98,  3.86,  4.12,
#         3.38,  3.19,  3.43,  3.06,  3.46,  3.24,  3.22,  3.42,  3.69,
#         3.28,  3.12,  3.  ,  3.62,  3.5 ,  4.42,  4.5 ,  5.19,  5.63,
#         5.73,  4.98,  5.23,  6.29,  5.78,  5.62,  6.3 ,  6.6 ,  6.55,
#         6.13,  6.15,  6.05,  5.87,  5.66,  5.85,  5.36,  5.22,  5.96,
#         5.97,  5.39,  5.16,  4.45,  4.05,  3.61,  2.71,  2.51,  2.59,
#         1.83,  1.39,  1.44,  1.32, 99.  ,  1.14,  1.12,  1.37,  1.15,
#         1.86,  2.19,  2.79,  3.07,  3.23,  3.25,  4.03,  4.  ,  3.66,
#         3.73,  2.58,  1.96,  2.37,  2.08,  1.72,  1.59,  1.46,  1.76,
#         1.61,  0.83,  0.87,  0.89,  0.9 ,  2.53,  2.94,  2.98,  3.04,
#         2.84,  2.63,  2.82,  2.5 ,  2.41,  2.  ,  1.78,  2.29,  3.34,
#         3.93,  5.04,  5.75,  6.02,  6.54,  6.03,  6.27,  5.81,  5.69,
#         5.6 ,  6.38,  5.56,  5.7 ,  5.15,  5.32,  5.14,  4.78,  5.03,
#         4.68,  4.86,  4.28,  4.88,  4.52,  4.1 ,  4.25,  3.81,  3.32,
#         3.13,  1.9 ,  1.84,  1.54,  1.21,  2.23,  2.93,  2.88,  3.02,
#         2.89,  2.57,  1.64,  0.88,  0.85,  0.86,  0.84,  0.81,  0.74,
#         0.82,  0.78,  0.79,  0.91,  3.56,  3.63,  2.77,  2.67,  2.24,
#         2.7 ,  1.27,  3.15,  3.2 ,  3.49,  3.21,  2.66,  3.68,  4.41,
#         4.94,  5.11,  5.27,  5.26,  5.68,  5.3 ,  4.27,  5.35,  5.08,
#         4.43,  3.45,  3.14,  2.85,  2.87,  3.11,  3.51,  3.79,  3.48,
#         2.96])

# %%
data = data[data['WVHT'] != 99]

# %%
data.shape
# Out:
# (2155, 2)

# %%
data['WVHT'].plot(figsize=(8,6))
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data = data.sort_values(by='date_time')
y = data['WVHT'].values

# %%
# Define a function to prepare sequences
def prepare_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

# %%
# Prepare sequences and targets
sequence_length = 100  # Adjust as needed
x_seq, y_targets = prepare_sequences(y, sequence_length)

# %%
# Split the data into train and test sets
split_ratio = 0.7  # Adjust as needed
split_idx = int(split_ratio * len(x_seq))
x_train, x_test = x_seq[:split_idx], x_seq[split_idx:]
y_train, y_test = y_targets[:split_idx], y_targets[split_idx:]

# %%
# Define quantile loss function using TensorFlow operations
def quantile_loss(q, y_true, y_pred):
    error = y_true - y_pred
    return tf.reduce_mean(tf.maximum(q * error, (q - 1) * error))

# %%
# Import the Dropout layer from TensorFlow
from tensorflow.keras.layers import Dropout

# %%
from tensorflow.keras.layers import Input, GRU, LSTM, Dropout, Dense, Concatenate
from tensorflow.keras.models import Model
import tensorflow as tf
from keras.utils import plot_model, model_to_dot

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, LSTM, SimpleRNN, Concatenate, Dense
from tensorflow.keras.optimizers import Adam

def train_model_with_quantile_loss(q):
    # Define input shape
    input_shape = (sequence_length, 1)
    inputs = Input(shape=input_shape)

    # RNN layer
    SimpleRNN_output = SimpleRNN(64, activation='relu')(inputs)

    # LSTM layer
    lstm_output = LSTM(64, activation='sigmoid')(inputs)

    # Concatenate the outputs of three layers
    concatenated = Concatenate()([SimpleRNN_output, lstm_output])

    # Dense layer
    dense_output = Dense(64, activation='relu')(concatenated)

    # Output layer
    output = Dense(1)(dense_output)

    # Create the model
    model = Model(inputs=inputs, outputs=output)

    # Compile the model with quantile loss
    model.compile(optimizer=Adam(learning_rate=0.001), loss=lambda y_true, y_pred: quantile_loss(q, y_true, y_pred))

    # Train the model
    model.fit(x_train, y_train, validation_split=0.1, epochs=100, batch_size=80, verbose=1)

    return model

# %%
#Train models with 20% and 80% quantiles
q_05 = 0.05  # 10% quantile
model_05 = train_model_with_quantile_loss(q_05)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 5s 105ms/step - loss: 0.0628 - val_loss: 0.0244
# Epoch 2/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0244 - val_loss: 0.0138
# Epoch 3/100
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0169 - val_loss: 0.0134
# Epoch 4/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0165 - val_loss: 0.0135
# Epoch 5/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0169 - val_loss: 0.0168
# Epoch 6/100
# 17/17 [==============================] - 1s 89ms/step - loss: 0.0167 - val_loss: 0.0136
# Epoch 7/100
# 17/17 [==============================] - 2s 123ms/step - loss: 0.0175 - val_loss: 0.0129
# Epoch 8/100
# 17/17 [==============================] - 2s 140ms/step - loss: 0.0151 - val_loss: 0.0156
# Epoch 9/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0160 - val_loss: 0.0170
# Epoch 10/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0162 - val_loss: 0.0132
# Epoch 11/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0171 - val_loss: 0.0146
# Epoch 12/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0169 - val_loss: 0.0161
# Epoch 13/100
# 17/17 [==============================] - 2s 90ms/step - loss: 0.0179 - val_loss: 0.0132
# Epoch 14/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0144 - val_loss: 0.0133
# Epoch 15/100
# 17/17 [==============================] - 2s 99ms/step - loss: 0.0144 - val_loss: 0.0149
# Epoch 16/100
# 17/17 [==============================] - 2s 131ms/step - loss: 0.0153 - val_loss: 0.0136
# Epoch 17/100
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0142 - val_loss: 0.0213
# Epoch 18/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0185 - val_loss: 0.0182
# Epoch 19/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0161 - val_loss: 0.0146
# Epoch 20/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0151 - val_loss: 0.0131
# Epoch 21/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0146 - val_loss: 0.0138
# Epoch 22/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0143 - val_loss: 0.0133
# Epoch 23/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0152 - val_loss: 0.0131
# Epoch 24/100
# 17/17 [==============================] - 2s 118ms/step - loss: 0.0153 - val_loss: 0.0129
# Epoch 25/100
# 17/17 [==============================] - 2s 132ms/step - loss: 0.0145 - val_loss: 0.0168
# Epoch 26/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0155 - val_loss: 0.0137
# Epoch 27/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0144 - val_loss: 0.0132
# Epoch 28/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0142 - val_loss: 0.0136
# Epoch 29/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0146 - val_loss: 0.0140
# Epoch 30/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0153 - val_loss: 0.0184
# Epoch 31/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0159 - val_loss: 0.0142
# Epoch 32/100
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0145 - val_loss: 0.0134
# Epoch 33/100
# 17/17 [==============================] - 2s 134ms/step - loss: 0.0164 - val_loss: 0.0137
# Epoch 34/100
# 17/17 [==============================] - 2s 113ms/step - loss: 0.0145 - val_loss: 0.0135
# Epoch 35/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0160 - val_loss: 0.0141
# Epoch 36/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0151 - val_loss: 0.0131
# Epoch 37/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0143 - val_loss: 0.0129
# Epoch 38/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0144 - val_loss: 0.0139
# Epoch 39/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0145 - val_loss: 0.0132
# Epoch 40/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0147 - val_loss: 0.0129
# Epoch 41/100
# 17/17 [==============================] - 2s 121ms/step - loss: 0.0143 - val_loss: 0.0130
# Epoch 42/100
# 17/17 [==============================] - 2s 145ms/step - loss: 0.0148 - val_loss: 0.0144
# Epoch 43/100
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0145 - val_loss: 0.0131
# Epoch 44/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0147 - val_loss: 0.0142
# Epoch 45/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0144 - val_loss: 0.0131
# Epoch 46/100
# 17/17 [==============================] - 2s 90ms/step - loss: 0.0143 - val_loss: 0.0134
# Epoch 47/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0145 - val_loss: 0.0129
# Epoch 48/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0143 - val_loss: 0.0149
# Epoch 49/100
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0145 - val_loss: 0.0131
# Epoch 50/100
# 17/17 [==============================] - 2s 137ms/step - loss: 0.0144 - val_loss: 0.0128
# Epoch 51/100
# 17/17 [==============================] - 2s 121ms/step - loss: 0.0146 - val_loss: 0.0127
# Epoch 52/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0143 - val_loss: 0.0148
# Epoch 53/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0144 - val_loss: 0.0127
# Epoch 54/100
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0143 - val_loss: 0.0137
# Epoch 55/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0144 - val_loss: 0.0153
# Epoch 56/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0147 - val_loss: 0.0142
# Epoch 57/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0145 - val_loss: 0.0129
# Epoch 58/100
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0140 - val_loss: 0.0138
# Epoch 59/100
# 17/17 [==============================] - 2s 138ms/step - loss: 0.0151 - val_loss: 0.0127
# Epoch 60/100
# 17/17 [==============================] - 2s 88ms/step - loss: 0.0146 - val_loss: 0.0139
# Epoch 61/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0169 - val_loss: 0.0134
# Epoch 62/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0148 - val_loss: 0.0140
# Epoch 63/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0143 - val_loss: 0.0128
# Epoch 64/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0155 - val_loss: 0.0160
# Epoch 65/100
# 17/17 [==============================] - 2s 96ms/step - loss: 0.0174 - val_loss: 0.0132
# Epoch 66/100
# 17/17 [==============================] - 2s 98ms/step - loss: 0.0142 - val_loss: 0.0135
# Epoch 67/100
# 17/17 [==============================] - 2s 143ms/step - loss: 0.0141 - val_loss: 0.0128
# Epoch 68/100
# 17/17 [==============================] - 2s 118ms/step - loss: 0.0156 - val_loss: 0.0144
# Epoch 69/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0152 - val_loss: 0.0147
# Epoch 70/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0147 - val_loss: 0.0163
# Epoch 71/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0146 - val_loss: 0.0130
# Epoch 72/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0146 - val_loss: 0.0130
# Epoch 73/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0153 - val_loss: 0.0203
# Epoch 74/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0172 - val_loss: 0.0137
# Epoch 75/100
# 17/17 [==============================] - 2s 127ms/step - loss: 0.0159 - val_loss: 0.0136
# Epoch 76/100
# 17/17 [==============================] - 2s 141ms/step - loss: 0.0149 - val_loss: 0.0140
# Epoch 77/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0146 - val_loss: 0.0137
# Epoch 78/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0142 - val_loss: 0.0154
# Epoch 79/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0143 - val_loss: 0.0142
# Epoch 80/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0158 - val_loss: 0.0137
# Epoch 81/100
# 17/17 [==============================] - 2s 96ms/step - loss: 0.0141 - val_loss: 0.0128
# Epoch 82/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0140 - val_loss: 0.0140
# Epoch 83/100
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0144 - val_loss: 0.0148
# Epoch 84/100
# 17/17 [==============================] - 2s 139ms/step - loss: 0.0171 - val_loss: 0.0153
# Epoch 85/100
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0150 - val_loss: 0.0137
# Epoch 86/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0140 - val_loss: 0.0136
# Epoch 87/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0146 - val_loss: 0.0127
# Epoch 88/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0185 - val_loss: 0.0133
# Epoch 89/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0151 - val_loss: 0.0137
# Epoch 90/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0145 - val_loss: 0.0129
# Epoch 91/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0143 - val_loss: 0.0137
# Epoch 92/100
# 17/17 [==============================] - 2s 123ms/step - loss: 0.0144 - val_loss: 0.0128
# Epoch 93/100
# 17/17 [==============================] - 2s 140ms/step - loss: 0.0142 - val_loss: 0.0129
# Epoch 94/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0140 - val_loss: 0.0153
# Epoch 95/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0142 - val_loss: 0.0132
# Epoch 96/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 97/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0143 - val_loss: 0.0132
# Epoch 98/100
# 17/17 [==============================] - 2s 90ms/step - loss: 0.0144 - val_loss: 0.0153
# Epoch 99/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0143 - val_loss: 0.0149
# Epoch 100/100
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0148 - val_loss: 0.0138

# %%
q_95 = 0.95  # 90% quantile
model_95 = train_model_with_quantile_loss(q_95)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 4s 112ms/step - loss: 0.8126 - val_loss: 0.1071
# Epoch 2/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.1174 - val_loss: 0.0928
# Epoch 3/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0767 - val_loss: 0.0557
# Epoch 4/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0572 - val_loss: 0.0452
# Epoch 5/100
# 17/17 [==============================] - 2s 143ms/step - loss: 0.0401 - val_loss: 0.0310
# Epoch 6/100
# 17/17 [==============================] - 3s 150ms/step - loss: 0.0284 - val_loss: 0.0243
# Epoch 7/100
# 17/17 [==============================] - 2s 144ms/step - loss: 0.0253 - val_loss: 0.0273
# Epoch 8/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0232 - val_loss: 0.0192
# Epoch 9/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0210 - val_loss: 0.0185
# Epoch 10/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0202 - val_loss: 0.0190
# Epoch 11/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0217 - val_loss: 0.0181
# Epoch 12/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0203 - val_loss: 0.0193
# Epoch 13/100
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0226 - val_loss: 0.0200
# Epoch 14/100
# 17/17 [==============================] - 2s 138ms/step - loss: 0.0210 - val_loss: 0.0175
# Epoch 15/100
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0191 - val_loss: 0.0241
# Epoch 16/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0220 - val_loss: 0.0166
# Epoch 17/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0202 - val_loss: 0.0181
# Epoch 18/100
# 17/17 [==============================] - 2s 91ms/step - loss: 0.0194 - val_loss: 0.0167
# Epoch 19/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0188 - val_loss: 0.0184
# Epoch 20/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0196 - val_loss: 0.0163
# Epoch 21/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0188 - val_loss: 0.0164
# Epoch 22/100
# 17/17 [==============================] - 2s 139ms/step - loss: 0.0190 - val_loss: 0.0171
# Epoch 23/100
# 17/17 [==============================] - 2s 122ms/step - loss: 0.0194 - val_loss: 0.0162
# Epoch 24/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0193 - val_loss: 0.0193
# Epoch 25/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0196 - val_loss: 0.0170
# Epoch 26/100
# 17/17 [==============================] - 2s 88ms/step - loss: 0.0197 - val_loss: 0.0164
# Epoch 27/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0193 - val_loss: 0.0172
# Epoch 28/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0195 - val_loss: 0.0162
# Epoch 29/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0185 - val_loss: 0.0162
# Epoch 30/100
# 17/17 [==============================] - 2s 124ms/step - loss: 0.0203 - val_loss: 0.0150
# Epoch 31/100
# 17/17 [==============================] - 2s 138ms/step - loss: 0.0191 - val_loss: 0.0157
# Epoch 32/100
# 17/17 [==============================] - 2s 92ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 33/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0185 - val_loss: 0.0162
# Epoch 34/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0192 - val_loss: 0.0187
# Epoch 35/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0193 - val_loss: 0.0156
# Epoch 36/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0197 - val_loss: 0.0182
# Epoch 37/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0193 - val_loss: 0.0165
# Epoch 38/100
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0183 - val_loss: 0.0158
# Epoch 39/100
# 17/17 [==============================] - 2s 140ms/step - loss: 0.0190 - val_loss: 0.0158
# Epoch 40/100
# 17/17 [==============================] - 2s 117ms/step - loss: 0.0194 - val_loss: 0.0158
# Epoch 41/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0221 - val_loss: 0.0159
# Epoch 42/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0191 - val_loss: 0.0158
# Epoch 43/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0187 - val_loss: 0.0169
# Epoch 44/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0186 - val_loss: 0.0171
# Epoch 45/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0196 - val_loss: 0.0167
# Epoch 46/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0193 - val_loss: 0.0163
# Epoch 47/100
# 17/17 [==============================] - 2s 113ms/step - loss: 0.0198 - val_loss: 0.0170
# Epoch 48/100
# 17/17 [==============================] - 2s 136ms/step - loss: 0.0193 - val_loss: 0.0178
# Epoch 49/100
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0186 - val_loss: 0.0156
# Epoch 50/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0198 - val_loss: 0.0161
# Epoch 51/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0187 - val_loss: 0.0170
# Epoch 52/100
# 17/17 [==============================] - 2s 91ms/step - loss: 0.0192 - val_loss: 0.0163
# Epoch 53/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0200 - val_loss: 0.0185
# Epoch 54/100
# 17/17 [==============================] - 2s 92ms/step - loss: 0.0197 - val_loss: 0.0155
# Epoch 55/100
# 17/17 [==============================] - 2s 96ms/step - loss: 0.0192 - val_loss: 0.0235
# Epoch 56/100
# 17/17 [==============================] - 2s 143ms/step - loss: 0.0205 - val_loss: 0.0178
# Epoch 57/100
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0188 - val_loss: 0.0159
# Epoch 58/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0192 - val_loss: 0.0160
# Epoch 59/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0189 - val_loss: 0.0150
# Epoch 60/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0201 - val_loss: 0.0187
# Epoch 61/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0199 - val_loss: 0.0162
# Epoch 62/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0194 - val_loss: 0.0172
# Epoch 63/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0183 - val_loss: 0.0167
# Epoch 64/100
# 17/17 [==============================] - 2s 120ms/step - loss: 0.0187 - val_loss: 0.0180
# Epoch 65/100
# 17/17 [==============================] - 2s 137ms/step - loss: 0.0191 - val_loss: 0.0166
# Epoch 66/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0229 - val_loss: 0.0156
# Epoch 67/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0201 - val_loss: 0.0161
# Epoch 68/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0206 - val_loss: 0.0156
# Epoch 69/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0190 - val_loss: 0.0163
# Epoch 70/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0181 - val_loss: 0.0158
# Epoch 71/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0182 - val_loss: 0.0153
# Epoch 72/100
# 17/17 [==============================] - 2s 98ms/step - loss: 0.0190 - val_loss: 0.0157
# Epoch 73/100
# 17/17 [==============================] - 2s 136ms/step - loss: 0.0190 - val_loss: 0.0158
# Epoch 74/100
# 17/17 [==============================] - 2s 117ms/step - loss: 0.0184 - val_loss: 0.0153
# Epoch 75/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0181 - val_loss: 0.0160
# Epoch 76/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0183 - val_loss: 0.0159
# Epoch 77/100
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0179 - val_loss: 0.0155
# Epoch 78/100
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0181 - val_loss: 0.0161
# Epoch 79/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0180 - val_loss: 0.0159
# Epoch 80/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0190 - val_loss: 0.0169
# Epoch 81/100
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0188 - val_loss: 0.0168
# Epoch 82/100
# 17/17 [==============================] - 2s 134ms/step - loss: 0.0193 - val_loss: 0.0159
# Epoch 83/100
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0186 - val_loss: 0.0154
# Epoch 84/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0177 - val_loss: 0.0153
# Epoch 85/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0184 - val_loss: 0.0153
# Epoch 86/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0179 - val_loss: 0.0169
# Epoch 87/100
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0197 - val_loss: 0.0174
# Epoch 88/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0195 - val_loss: 0.0152
# Epoch 89/100
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0210 - val_loss: 0.0158
# Epoch 90/100
# 17/17 [==============================] - 2s 131ms/step - loss: 0.0181 - val_loss: 0.0163
# Epoch 91/100
# 17/17 [==============================] - 2s 124ms/step - loss: 0.0179 - val_loss: 0.0161
# Epoch 92/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0189 - val_loss: 0.0171
# Epoch 93/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 94/100
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0201 - val_loss: 0.0161
# Epoch 95/100
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0189 - val_loss: 0.0151
# Epoch 96/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0181 - val_loss: 0.0154
# Epoch 97/100
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0182 - val_loss: 0.0156
# Epoch 98/100
# 17/17 [==============================] - 2s 116ms/step - loss: 0.0183 - val_loss: 0.0154
# Epoch 99/100
# 17/17 [==============================] - 2s 138ms/step - loss: 0.0180 - val_loss: 0.0160
# Epoch 100/100
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0176 - val_loss: 0.0160

# %%
# Make predictions
y_pred_05 = model_05.predict(x_test)
y_pred_95 = model_95.predict(x_test)
# Out:
# 20/20 [==============================] - 1s 17ms/step
# 20/20 [==============================] - 1s 19ms/step

# %%
# Plot quantile predictions along with actual values
plt.plot(range(len(y_test)), y_test, label="Actual")
plt.plot(range(len(y_test)), y_pred_05, label="5% Prediction")
plt.plot(range(len(y_test)), y_pred_95, label="95% Prediction")
plt.xlabel("Data Points in Test Set")
plt.ylabel("WVHT")
plt.legend()
plt.savefig('41002h2021.png')
plt.show()

# Calculate the number of points between 95% and 5% percentiles
num_points_between_percentiles = np.sum((y_pred_05 <= y_test) & (y_test <= y_pred_95))

# %%
# Calculate MPIW
def calculate_mpiw(y_lower, y_upper):
    mpiw = np.mean(y_upper - y_lower)
    return mpiw

# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Calculate MPIW for the 10-90% prediction interval
mpiw = calculate_mpiw(y_lower_05, y_upper_95)

# Print MPIW for the 10-90% prediction interval
print("MPIW:", mpiw)
# Out:
# MPIW: 0.48166716

# %%
print(len(y_test))
# Out:
# 617

# %%
# Check if each actual observation falls within the prediction interval
within_interval = (y_pred_05.flatten() <= y_test) & (y_test <= y_pred_95.flatten())
print(within_interval.sum())
# Out:
# 556

# %%
# Check if each actual observation falls within the prediction interval
within_interval = (y_pred_05.flatten() <= y_test) & (y_test <= y_pred_95.flatten())

# Count the number of observations falling within the prediction intervals
num_within_interval = within_interval.sum()

# Total number of observations
total_observations = len(y_test)

# Calculate PICP (Prediction Interval Coverage Probability)
picp = num_within_interval / total_observations
print("PICP:", picp)
# Out:
# PICP: 0.9011345218800648
