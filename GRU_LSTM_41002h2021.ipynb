# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
# Assuming your text file is named "data.txt" and is in the same directory as your Python script
file_path = "/content/41002h2021 (1).txt"

# If your data is separated by spaces, you can use:
df = pd.read_csv(file_path, delim_whitespace=True)

# %%
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD    APD  MWD    PRES  \
# 0  2021   6   8   3  30   164   3.8  4.6  99.00  99.00  99.00  999  1023.3
# 1  2021   6   8   3  40   167   3.6  4.4   0.91   7.69   5.65  129  1023.2
# 2  2021   6   8   3  50   163   3.5  4.2  99.00  99.00  99.00  999  1023.1
# 3  2021   6   8   4   0   158   3.5  4.3  99.00  99.00  99.00  999  1023.1
# 4  2021   6   8   4  10   156   3.6  4.5  99.00  99.00  99.00  999  1023.3
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 0  25.8  25.9  23.5  99.0  99.0
# 1  25.8  25.9  23.4  99.0  99.0
# 2  25.8  25.9  23.5  99.0  99.0
# 3  25.7  25.9  23.5  99.0  99.0
# 4  25.7  25.9  23.5  99.0  99.0

# %%
# Remove the first row
df = df.iloc[1:]
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD    APD  MWD    PRES  \
# 1  2021   6   8   3  40   167   3.6  4.4   0.91   7.69   5.65  129  1023.2
# 2  2021   6   8   3  50   163   3.5  4.2  99.00  99.00  99.00  999  1023.1
# 3  2021   6   8   4   0   158   3.5  4.3  99.00  99.00  99.00  999  1023.1
# 4  2021   6   8   4  10   156   3.6  4.5  99.00  99.00  99.00  999  1023.3
# 5  2021   6   8   4  20   155   3.7  4.6  99.00  99.00  99.00  999  1023.2
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 1  25.8  25.9  23.4  99.0  99.0
# 2  25.8  25.9  23.5  99.0  99.0
# 3  25.7  25.9  23.5  99.0  99.0
# 4  25.7  25.9  23.5  99.0  99.0
# 5  25.7  25.9  23.7  99.0  99.0

# %%
df.shape
# Out:
# (12214, 18)

# %%
# Convert specific columns to numeric values
columns_to_convert = ['#YY', 'MM', 'DD', 'hh', 'mm', 'WDIR', 'WSPD', 'GST', 'WVHT', 'DPD', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP', 'VIS', 'TIDE']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')
# Alternatively, convert all object columns to numeric values
df = df.apply(pd.to_numeric, errors='coerce')
# Out:
# <ipython-input-45-027fd0094cd0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# Extract rows where mm=0
df = df[df["mm"] == 40]

# %%
#here we reset the index
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (2037, 18)

# %%
df.isnull().sum()
# Out:
# #YY     0
# MM      0
# DD      0
# hh      0
# mm      0
# WDIR    0
# WSPD    0
# GST     0
# WVHT    0
# DPD     0
# APD     0
# MWD     0
# PRES    0
# ATMP    0
# WTMP    0
# DEWP    0
# VIS     0
# TIDE    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (2037, 18)

# %%
# Combine date and time columns into a single datetime column
df['date_time'] = pd.to_datetime(df[['#YY', 'MM', 'DD', 'hh', 'mm']].astype(str).apply(' '.join, axis=1), format='%Y %m %d %H %M')

# %%
# Drop 5 columns by specifying their column labels
columns_to_drop = ['#YY', 'MM', 'DD', 'hh', 'mm']
df = df.drop(columns=columns_to_drop)

# %%
#Move the 'date_time' column to the first position
date_time_column = df.pop('date_time')
df.insert(0, 'date_time', date_time_column)

# %%
df.head()
# Out:
#             date_time  WDIR  WSPD  GST  WVHT   DPD   APD  MWD    PRES  ATMP  \
# 0 2021-06-08 03:40:00   167   3.6  4.4  0.91  7.69  5.65  129  1023.2  25.8
# 1 2021-06-08 04:40:00   163   3.8  4.5  0.83  7.69  5.53  132  1023.2  25.7
# 2 2021-06-08 05:40:00   167   4.1  5.1  0.85  7.69  5.44  129  1022.8  25.5
# 3 2021-06-08 06:40:00   180   3.7  4.4  0.95  8.33  5.70  119  1022.7  25.5
# 4 2021-06-08 07:40:00   180   3.4  4.3  0.90  8.33  5.74  121  1022.3  25.5
#
#    WTMP  DEWP   VIS  TIDE
# 0  25.9  23.4  99.0  99.0
# 1  25.9  23.5  99.0  99.0
# 2  25.7  23.4  99.0  99.0
# 3  25.8  23.5  99.0  99.0
# 4  25.9  23.6  99.0  99.0

# %%
df["WVHT"]=df["WVHT"].astype(float)

# %%
# Assuming you have a DataFrame called 'df'
selected_columns = ['date_time' , 'WVHT']  # Specify the columns you want to select

data = df[selected_columns]  # Create a new DataFrame by selecting the specified columns

# Print the new DataFrame
print(data)
# Out:
#                date_time  WVHT
# 0    2021-06-08 03:40:00  0.91
# 1    2021-06-08 04:40:00  0.83
# 2    2021-06-08 05:40:00  0.85
# 3    2021-06-08 06:40:00  0.95
# 4    2021-06-08 07:40:00  0.90
# ...                  ...   ...
# 2032 2021-08-31 19:40:00  0.86
# 2033 2021-08-31 20:40:00  0.88
# 2034 2021-08-31 21:40:00  0.91
# 2035 2021-08-31 22:40:00  0.88
# 2036 2021-08-31 23:40:00  0.82
#
# [2037 rows x 2 columns]

# %%
unique_values = data['WVHT'].unique()
unique_values
# Out:
# array([ 0.91,  0.83,  0.85,  0.95,  0.9 ,  1.01,  0.93,  0.97,  1.  ,
#         1.02,  1.03,  0.94,  0.98,  0.99,  0.88,  0.89,  0.96,  0.84,
#         1.07,  1.05,  1.13,  1.12,  1.06,  1.11,  1.04,  1.1 ,  1.09,
#         1.15,  1.34,  1.33,  1.3 ,  1.38, 99.  ,  1.4 ,  1.46,  1.48,
#         1.44,  1.41,  1.39,  1.37,  1.49,  1.42,  1.51,  1.56,  1.63,
#         1.53,  1.71,  1.64,  1.7 ,  1.84,  1.87,  1.83,  1.98,  2.03,
#         1.95,  2.16,  2.08,  2.14,  2.12,  2.19,  2.17,  1.93,  2.07,
#         1.88,  1.75,  1.74,  1.68,  1.78,  1.66,  1.72,  1.8 ,  1.76,
#         1.81,  1.77,  1.85,  1.69,  1.65,  1.73,  1.67,  1.82,  1.92,
#         1.35,  1.27,  1.2 ,  1.31,  1.32,  1.54,  1.45,  2.02,  2.09,
#         2.26,  2.33,  2.24,  2.31,  2.22,  1.96,  1.91,  1.55,  1.43,
#         1.57,  1.26,  1.29,  1.21,  1.25,  1.28,  1.14,  0.81,  0.75,
#         0.77,  0.79,  0.8 ,  0.72,  0.76,  0.71,  0.74,  0.69,  0.7 ,
#         0.67,  0.73,  0.78,  0.82,  0.87,  2.01,  2.2 ,  2.34,  2.23,
#         2.15,  2.28,  2.3 ,  2.38,  2.1 ,  1.86,  1.9 ,  2.04,  2.06,
#         1.79,  1.59,  1.6 ,  1.5 ,  1.24,  1.16,  1.47,  1.62,  1.61,
#         1.58,  1.17,  1.23,  1.19,  1.18,  1.36,  2.32,  2.84,  3.43,
#         3.47,  3.29,  3.13,  2.7 ,  2.55,  2.49,  1.08,  0.92,  0.86,
#         0.68,  1.22,  2.43,  2.62,  2.79,  2.83,  2.76,  2.72,  2.66,
#         2.77,  2.42,  2.63,  2.64,  2.48,  2.4 ,  2.88,  2.95,  2.86,
#         3.01,  2.94,  3.14,  2.58,  2.74,  2.29,  2.18,  2.39,  2.27,
#         2.11,  1.89,  1.52,  0.66,  0.58,  0.63,  1.94,  1.99,  2.35,
#         2.21,  2.44,  2.69,  2.56,  2.45,  2.25,  2.05,  0.64,  0.65,
#         0.62,  0.61,  0.59,  0.6 ,  0.54,  0.55,  0.57,  0.56,  2.47,
#         2.98,  2.61,  2.8 ,  3.26,  3.2 ,  2.97,  2.36,  2.  ])

# %%
data = data[data['WVHT'] != 99]

# %%
data.shape
# Out:
# (2030, 2)

# %%
data['WVHT'].plot(figsize=(8,6))
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data = data.sort_values(by='date_time')
y = data['WVHT'].values

# %%
# Define a function to prepare sequences
def prepare_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

# %%
# Prepare sequences and targets
sequence_length = 100  # Adjust as needed
x_seq, y_targets = prepare_sequences(y, sequence_length)

# %%
# Split the data into train and test sets
split_ratio = 0.7  # Adjust as needed
split_idx = int(split_ratio * len(x_seq))
x_train, x_test = x_seq[:split_idx], x_seq[split_idx:]
y_train, y_test = y_targets[:split_idx], y_targets[split_idx:]

# %%
# Define quantile loss function using TensorFlow operations
def quantile_loss(q, y_true, y_pred):
    error = y_true - y_pred
    return tf.reduce_mean(tf.maximum(q * error, (q - 1) * error))

# %%
# Import the Dropout layer from TensorFlow
from tensorflow.keras.layers import Dropout

# %%
from tensorflow.keras.layers import Input, GRU, LSTM, Dropout, Dense, Concatenate
from tensorflow.keras.models import Model
import tensorflow as tf
from keras.utils import plot_model, model_to_dot

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, LSTM, SimpleRNN, Concatenate, Dense
from tensorflow.keras.optimizers import Adam

def train_model_with_quantile_loss(q):
    # Define input shape
    input_shape = (sequence_length, 1)
    inputs = Input(shape=input_shape)

    # GRU layer
    gru_output = GRU(64, activation='sigmoid')(inputs)

    # LSTM layer
    lstm_output = LSTM(64, activation='sigmoid')(inputs)

    # Concatenate the outputs of three layers
    concatenated = Concatenate()([gru_output, lstm_output])

    # Dense layer
    dense_output = Dense(64, activation='relu')(concatenated)

    # Output layer
    output = Dense(1)(dense_output)

    # Create the model
    model = Model(inputs=inputs, outputs=output)

    # Compile the model with quantile loss
    model.compile(optimizer=Adam(learning_rate=0.0001), loss=lambda y_true, y_pred: quantile_loss(q, y_true, y_pred))

    # Train the model
    model.fit(x_train, y_train, validation_split=0.1, epochs=100, batch_size=32, verbose=1)

    return model

# %%
#Train models with 20% and 80% quantiles
q_05 = 0.05  # 10% quantile
model_05 = train_model_with_quantile_loss(q_05)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 5s 74ms/step - loss: 0.0309 - val_loss: 0.0502
# Epoch 2/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0289 - val_loss: 0.0489
# Epoch 3/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0287 - val_loss: 0.0473
# Epoch 4/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0288 - val_loss: 0.0502
# Epoch 5/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0282 - val_loss: 0.0490
# Epoch 6/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0282 - val_loss: 0.0479
# Epoch 7/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0279 - val_loss: 0.0494
# Epoch 8/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0280 - val_loss: 0.0486
# Epoch 9/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0276 - val_loss: 0.0477
# Epoch 10/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0272 - val_loss: 0.0459
# Epoch 11/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0270 - val_loss: 0.0460
# Epoch 12/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0268 - val_loss: 0.0446
# Epoch 13/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0268 - val_loss: 0.0456
# Epoch 14/100
# 38/38 [==============================] - 3s 65ms/step - loss: 0.0263 - val_loss: 0.0429
# Epoch 15/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0263 - val_loss: 0.0467
# Epoch 16/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0263 - val_loss: 0.0434
# Epoch 17/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0257 - val_loss: 0.0450
# Epoch 18/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0256 - val_loss: 0.0430
# Epoch 19/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0252 - val_loss: 0.0433
# Epoch 20/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0250 - val_loss: 0.0427
# Epoch 21/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0247 - val_loss: 0.0417
# Epoch 22/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0244 - val_loss: 0.0410
# Epoch 23/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0242 - val_loss: 0.0421
# Epoch 24/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0239 - val_loss: 0.0392
# Epoch 25/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0235 - val_loss: 0.0396
# Epoch 26/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0232 - val_loss: 0.0400
# Epoch 27/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0227 - val_loss: 0.0373
# Epoch 28/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0225 - val_loss: 0.0392
# Epoch 29/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0221 - val_loss: 0.0360
# Epoch 30/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0218 - val_loss: 0.0359
# Epoch 31/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0215 - val_loss: 0.0351
# Epoch 32/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0209 - val_loss: 0.0349
# Epoch 33/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0206 - val_loss: 0.0350
# Epoch 34/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0201 - val_loss: 0.0306
# Epoch 35/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0197 - val_loss: 0.0327
# Epoch 36/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0193 - val_loss: 0.0316
# Epoch 37/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0187 - val_loss: 0.0301
# Epoch 38/100
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0182 - val_loss: 0.0271
# Epoch 39/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0182 - val_loss: 0.0285
# Epoch 40/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0173 - val_loss: 0.0266
# Epoch 41/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0169 - val_loss: 0.0256
# Epoch 42/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0161 - val_loss: 0.0260
# Epoch 43/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0157 - val_loss: 0.0244
# Epoch 44/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0149 - val_loss: 0.0229
# Epoch 45/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0143 - val_loss: 0.0223
# Epoch 46/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0138 - val_loss: 0.0216
# Epoch 47/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0131 - val_loss: 0.0187
# Epoch 48/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0129 - val_loss: 0.0187
# Epoch 49/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0119 - val_loss: 0.0183
# Epoch 50/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0113 - val_loss: 0.0171
# Epoch 51/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0109 - val_loss: 0.0171
# Epoch 52/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0106 - val_loss: 0.0144
# Epoch 53/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0101 - val_loss: 0.0140
# Epoch 54/100
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0099 - val_loss: 0.0139
# Epoch 55/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0104 - val_loss: 0.0134
# Epoch 56/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0095 - val_loss: 0.0128
# Epoch 57/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0094 - val_loss: 0.0127
# Epoch 58/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0093 - val_loss: 0.0126
# Epoch 59/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 60/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0092 - val_loss: 0.0127
# Epoch 61/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0095 - val_loss: 0.0129
# Epoch 62/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0094 - val_loss: 0.0124
# Epoch 63/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0092 - val_loss: 0.0123
# Epoch 64/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0091 - val_loss: 0.0123
# Epoch 65/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 66/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0091 - val_loss: 0.0123
# Epoch 67/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0095 - val_loss: 0.0133
# Epoch 68/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0090 - val_loss: 0.0127
# Epoch 69/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0090 - val_loss: 0.0121
# Epoch 70/100
# 38/38 [==============================] - 4s 112ms/step - loss: 0.0093 - val_loss: 0.0121
# Epoch 71/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0090 - val_loss: 0.0123
# Epoch 72/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0088 - val_loss: 0.0122
# Epoch 73/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0088 - val_loss: 0.0126
# Epoch 74/100
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0091 - val_loss: 0.0120
# Epoch 75/100
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0090 - val_loss: 0.0121
# Epoch 76/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0087 - val_loss: 0.0120
# Epoch 77/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0091 - val_loss: 0.0120
# Epoch 78/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0093 - val_loss: 0.0120
# Epoch 79/100
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0091 - val_loss: 0.0119
# Epoch 80/100
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0090 - val_loss: 0.0120
# Epoch 81/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0088 - val_loss: 0.0120
# Epoch 82/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0090 - val_loss: 0.0144
# Epoch 83/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0096 - val_loss: 0.0129
# Epoch 84/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 85/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0085 - val_loss: 0.0119
# Epoch 86/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0086 - val_loss: 0.0122
# Epoch 87/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0086 - val_loss: 0.0127
# Epoch 88/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0091 - val_loss: 0.0135
# Epoch 89/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0093 - val_loss: 0.0128
# Epoch 90/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0091 - val_loss: 0.0137
# Epoch 91/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0089 - val_loss: 0.0122
# Epoch 92/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0093 - val_loss: 0.0131
# Epoch 93/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0085 - val_loss: 0.0120
# Epoch 94/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0086 - val_loss: 0.0120
# Epoch 95/100
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0088 - val_loss: 0.0123
# Epoch 96/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0088 - val_loss: 0.0119
# Epoch 97/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0084 - val_loss: 0.0120
# Epoch 98/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0087 - val_loss: 0.0124
# Epoch 99/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0087 - val_loss: 0.0124
# Epoch 100/100
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0087 - val_loss: 0.0119

# %%
q_95 = 0.95  # 90% quantile
model_95 = train_model_with_quantile_loss(q_95)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 6s 80ms/step - loss: 0.9113 - val_loss: 0.9442
# Epoch 2/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.2858 - val_loss: 0.3976
# Epoch 3/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.1101 - val_loss: 0.1897
# Epoch 4/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0768 - val_loss: 0.1266
# Epoch 5/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0687 - val_loss: 0.1005
# Epoch 6/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0658 - val_loss: 0.0831
# Epoch 7/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0642 - val_loss: 0.0719
# Epoch 8/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0633 - val_loss: 0.0648
# Epoch 9/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0628 - val_loss: 0.0581
# Epoch 10/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0625 - val_loss: 0.0561
# Epoch 11/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0622 - val_loss: 0.0540
# Epoch 12/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0619 - val_loss: 0.0552
# Epoch 13/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0617 - val_loss: 0.0516
# Epoch 14/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0615 - val_loss: 0.0553
# Epoch 15/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0613 - val_loss: 0.0538
# Epoch 16/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0611 - val_loss: 0.0525
# Epoch 17/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0609 - val_loss: 0.0527
# Epoch 18/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0608 - val_loss: 0.0534
# Epoch 19/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0605 - val_loss: 0.0518
# Epoch 20/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0603 - val_loss: 0.0507
# Epoch 21/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0600 - val_loss: 0.0525
# Epoch 22/100
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0598 - val_loss: 0.0503
# Epoch 23/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0595 - val_loss: 0.0524
# Epoch 24/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0593 - val_loss: 0.0516
# Epoch 25/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0590 - val_loss: 0.0532
# Epoch 26/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0588 - val_loss: 0.0498
# Epoch 27/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0585 - val_loss: 0.0496
# Epoch 28/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0581 - val_loss: 0.0529
# Epoch 29/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0578 - val_loss: 0.0501
# Epoch 30/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0576 - val_loss: 0.0502
# Epoch 31/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0572 - val_loss: 0.0493
# Epoch 32/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0570 - val_loss: 0.0529
# Epoch 33/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0566 - val_loss: 0.0499
# Epoch 34/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0565 - val_loss: 0.0472
# Epoch 35/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0560 - val_loss: 0.0534
# Epoch 36/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0558 - val_loss: 0.0497
# Epoch 37/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0554 - val_loss: 0.0480
# Epoch 38/100
# 38/38 [==============================] - 4s 113ms/step - loss: 0.0551 - val_loss: 0.0487
# Epoch 39/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0548 - val_loss: 0.0486
# Epoch 40/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0543 - val_loss: 0.0498
# Epoch 41/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0539 - val_loss: 0.0489
# Epoch 42/100
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0535 - val_loss: 0.0440
# Epoch 43/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0531 - val_loss: 0.0480
# Epoch 44/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0527 - val_loss: 0.0441
# Epoch 45/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0520 - val_loss: 0.0497
# Epoch 46/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0515 - val_loss: 0.0467
# Epoch 47/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0510 - val_loss: 0.0466
# Epoch 48/100
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0506 - val_loss: 0.0419
# Epoch 49/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0498 - val_loss: 0.0469
# Epoch 50/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0494 - val_loss: 0.0426
# Epoch 51/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0490 - val_loss: 0.0414
# Epoch 52/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0486 - val_loss: 0.0465
# Epoch 53/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0475 - val_loss: 0.0456
# Epoch 54/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0468 - val_loss: 0.0421
# Epoch 55/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0460 - val_loss: 0.0420
# Epoch 56/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0455 - val_loss: 0.0387
# Epoch 57/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0446 - val_loss: 0.0400
# Epoch 58/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0441 - val_loss: 0.0318
# Epoch 59/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0429 - val_loss: 0.0340
# Epoch 60/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0414 - val_loss: 0.0423
# Epoch 61/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0407 - val_loss: 0.0393
# Epoch 62/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0396 - val_loss: 0.0382
# Epoch 63/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0382 - val_loss: 0.0345
# Epoch 64/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0372 - val_loss: 0.0372
# Epoch 65/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0358 - val_loss: 0.0314
# Epoch 66/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0345 - val_loss: 0.0357
# Epoch 67/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0335 - val_loss: 0.0386
# Epoch 68/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0318 - val_loss: 0.0396
# Epoch 69/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0305 - val_loss: 0.0308
# Epoch 70/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0288 - val_loss: 0.0280
# Epoch 71/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0273 - val_loss: 0.0281
# Epoch 72/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0256 - val_loss: 0.0205
# Epoch 73/100
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0244 - val_loss: 0.0238
# Epoch 74/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0228 - val_loss: 0.0192
# Epoch 75/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0220 - val_loss: 0.0254
# Epoch 76/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0194 - val_loss: 0.0192
# Epoch 77/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0183 - val_loss: 0.0168
# Epoch 78/100
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0170 - val_loss: 0.0162
# Epoch 79/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0158 - val_loss: 0.0162
# Epoch 80/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0149 - val_loss: 0.0146
# Epoch 81/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0137 - val_loss: 0.0138
# Epoch 82/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0139 - val_loss: 0.0145
# Epoch 83/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 84/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0132 - val_loss: 0.0137
# Epoch 85/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0127 - val_loss: 0.0131
# Epoch 86/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0132 - val_loss: 0.0132
# Epoch 87/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0123 - val_loss: 0.0128
# Epoch 88/100
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0134 - val_loss: 0.0131
# Epoch 89/100
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0123 - val_loss: 0.0127
# Epoch 90/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0131 - val_loss: 0.0127
# Epoch 91/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0121 - val_loss: 0.0126
# Epoch 92/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0121 - val_loss: 0.0135
# Epoch 93/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0118 - val_loss: 0.0128
# Epoch 94/100
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0120 - val_loss: 0.0133
# Epoch 95/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 96/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0120 - val_loss: 0.0124
# Epoch 97/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0119 - val_loss: 0.0129
# Epoch 98/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0116 - val_loss: 0.0131
# Epoch 99/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0117 - val_loss: 0.0138
# Epoch 100/100
# 38/38 [==============================] - 2s 63ms/step - loss: 0.0119 - val_loss: 0.0139

# %%
# Make predictions
y_pred_05 = model_05.predict(x_test)
y_pred_95 = model_95.predict(x_test)
# Out:
# 19/19 [==============================] - 1s 16ms/step
# 19/19 [==============================] - 1s 27ms/step

# %%
# Plot quantile predictions along with actual values
plt.plot(range(len(y_test)), y_test, label="Actual")
plt.plot(range(len(y_test)), y_pred_05, label="5% Prediction")
plt.plot(range(len(y_test)), y_pred_95, label="95% Prediction")
plt.xlabel("Data Points in Test Set")
plt.ylabel("WVHT")
plt.legend()
plt.savefig('41002h2021.png')
plt.show()

# Calculate the number of points between 95% and 5% percentiles
num_points_between_percentiles = np.sum((y_pred_05 <= y_test) & (y_test <= y_pred_95))

# %%
# Calculate MPIW
def calculate_mpiw(y_lower, y_upper):
    mpiw = np.mean(y_upper - y_lower)
    return mpiw

# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Calculate MPIW for the 10-90% prediction interval
mpiw = calculate_mpiw(y_lower_05, y_upper_95)

# Print MPIW for the 10-90% prediction interval
print("MPIW:", mpiw)
# Out:
# MPIW: 0.2906374

# %%
print(len(y_test))
# Out:
# 579

# %%
# Check if each actual observation falls within the prediction interval
within_interval = (y_pred_05.flatten() <= y_test) & (y_test <= y_pred_95.flatten())
print(within_interval.sum())
# Out:
# 542

# %%
# Check if each actual observation falls within the prediction interval
within_interval = (y_pred_05.flatten() <= y_test) & (y_test <= y_pred_95.flatten())

# Count the number of observations falling within the prediction intervals
num_within_interval = within_interval.sum()

# Total number of observations
total_observations = len(y_test)

# Calculate PICP (Prediction Interval Coverage Probability)
picp = num_within_interval / total_observations
print("PICP:", picp)
# Out:
# PICP: 0.9360967184801382
