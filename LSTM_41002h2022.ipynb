# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
# Assuming your text file is named "data.txt" and is in the same directory as your Python script
file_path = "/content/41002h2022.txt"

# If your data is separated by spaces, you can use:
df = pd.read_csv(file_path, delim_whitespace=True)

# %%
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD    APD  MWD    PRES  \
# 0  2022   1   1   0   0   304   1.7  3.0  99.00  99.00  99.00  999  1016.9
# 1  2022   1   1   0  10   289   2.0  2.8  99.00  99.00  99.00  999  1017.1
# 2  2022   1   1   0  20   292   2.5  3.7  99.00  99.00  99.00  999  1017.2
# 3  2022   1   1   0  30   285   1.8  3.1  99.00  99.00  99.00  999  1017.3
# 4  2022   1   1   0  40   292   1.8  3.0   1.73   7.14   6.05  270  1017.5
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 0  23.4  24.1  20.3  99.0  99.0
# 1  23.4  24.1  20.4  99.0  99.0
# 2  23.4  24.2  20.4  99.0  99.0
# 3  23.4  24.2  20.5  99.0  99.0
# 4  23.4  24.2  20.5  99.0  99.0

# %%
# Remove the first row
df = df.iloc[1:]
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD    APD  MWD    PRES  \
# 1  2022   1   1   0  10   289   2.0  2.8  99.00  99.00  99.00  999  1017.1
# 2  2022   1   1   0  20   292   2.5  3.7  99.00  99.00  99.00  999  1017.2
# 3  2022   1   1   0  30   285   1.8  3.1  99.00  99.00  99.00  999  1017.3
# 4  2022   1   1   0  40   292   1.8  3.0   1.73   7.14   6.05  270  1017.5
# 5  2022   1   1   0  50   289   2.0  3.0  99.00  99.00  99.00  999  1017.6
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 1  23.4  24.1  20.4  99.0  99.0
# 2  23.4  24.2  20.4  99.0  99.0
# 3  23.4  24.2  20.5  99.0  99.0
# 4  23.4  24.2  20.5  99.0  99.0
# 5  23.3  24.2  20.2  99.0  99.0

# %%
df.shape
# Out:
# (12948, 18)

# %%
# Convert specific columns to numeric values
columns_to_convert = ['#YY', 'MM', 'DD', 'hh', 'mm', 'WDIR', 'WSPD', 'GST', 'WVHT', 'DPD', 'APD', 'MWD', 'PRES', 'ATMP', 'WTMP', 'DEWP', 'VIS', 'TIDE']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')
# Alternatively, convert all object columns to numeric values
df = df.apply(pd.to_numeric, errors='coerce')

# %%
# Extract rows where mm=0
df = df[df["mm"] == 40]

# %%
#here we reset the index
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (2159, 18)

# %%
df.isnull().sum()
# Out:
# #YY     0
# MM      0
# DD      0
# hh      0
# mm      0
# WDIR    0
# WSPD    0
# GST     0
# WVHT    0
# DPD     0
# APD     0
# MWD     0
# PRES    0
# ATMP    0
# WTMP    0
# DEWP    0
# VIS     0
# TIDE    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (2159, 18)

# %%
# Combine date and time columns into a single datetime column
df['date_time'] = pd.to_datetime(df[['#YY', 'MM', 'DD', 'hh', 'mm']].astype(str).apply(' '.join, axis=1), format='%Y %m %d %H %M')

# %%
# Drop 5 columns by specifying their column labels
columns_to_drop = ['#YY', 'MM', 'DD', 'hh', 'mm']
df = df.drop(columns=columns_to_drop)

# %%
#Move the 'date_time' column to the first position
date_time_column = df.pop('date_time')
df.insert(0, 'date_time', date_time_column)

# %%
df.head()
# Out:
#             date_time  WDIR  WSPD  GST  WVHT   DPD   APD  MWD    PRES  ATMP  \
# 0 2022-01-01 00:40:00   292   1.8  3.0  1.73  7.14  6.05  270  1017.5  23.4
# 1 2022-01-01 01:40:00   238   1.6  2.5  1.58  7.14  5.76  259  1017.6  23.3
# 2 2022-01-01 02:40:00   250   2.5  3.6  1.68  7.14  6.13  269  1017.7  23.3
# 3 2022-01-01 03:40:00   238   3.5  4.6  1.52  6.67  5.82  268  1017.6  23.4
# 4 2022-01-01 04:40:00   230   4.9  6.1  1.50  7.14  6.02  254  1017.1  23.3
#
#    WTMP  DEWP   VIS  TIDE
# 0  24.2  20.5  99.0  99.0
# 1  24.3  20.5  99.0  99.0
# 2  24.3  20.9  99.0  99.0
# 3  24.3  20.6  99.0  99.0
# 4  24.3  20.7  99.0  99.0

# %%
df["WVHT"]=df["WVHT"].astype(float)

# %%
# Assuming you have a DataFrame called 'df'
selected_columns = ['date_time' , 'WVHT']  # Specify the columns you want to select

data = df[selected_columns]  # Create a new DataFrame by selecting the specified columns

# Print the new DataFrame
print(data)
# Out:
#                date_time  WVHT
# 0    2022-01-01 00:40:00  1.73
# 1    2022-01-01 01:40:00  1.58
# 2    2022-01-01 02:40:00  1.68
# 3    2022-01-01 03:40:00  1.52
# 4    2022-01-01 04:40:00  1.50
# ...                  ...   ...
# 2154 2022-03-31 19:40:00  2.10
# 2155 2022-03-31 20:40:00  2.26
# 2156 2022-03-31 21:40:00  2.45
# 2157 2022-03-31 22:40:00  2.32
# 2158 2022-03-31 23:40:00  2.11
#
# [2159 rows x 2 columns]

# %%
unique_values = data['WVHT'].unique()
unique_values
# Out:
# array([ 1.73,  1.58,  1.68,  1.52,  1.5 ,  1.29,  1.26,  1.2 ,  1.05,
#         1.02,  1.  ,  1.01,  0.96,  1.04,  1.13,  1.18,  1.24,  1.31,
#         1.33,  1.35,  1.49,  1.4 ,  1.51,  1.43,  1.48,  1.65,  1.85,
#         1.91,  2.01,  2.1 ,  2.17,  2.04,  2.27,  2.15,  2.31,  2.21,
#         2.14,  2.35,  2.28,  2.2 ,  2.22,  2.3 ,  2.11,  1.98,  2.13,
#         2.25,  2.34,  2.45,  2.43,  2.65,  2.44,  3.16,  3.27,  3.37,
#         3.53,  3.77,  3.96,  4.77,  5.17,  4.9 ,  5.28,  5.33,  6.19,
#         5.13,  4.85,  4.87,  4.13,  3.78,  4.01,  3.82,  3.89,  3.26,
#         4.08,  4.17,  4.19,  3.95,  3.91,  3.9 ,  3.75,  3.83,  3.74,
#         4.09,  4.31,  4.37,  4.49,  4.53,  4.67,  5.34,  4.51,  4.54,
#         3.71,  3.7 ,  3.55,  2.86,  2.92,  2.74,  2.64,  2.76,  2.62,
#         2.52,  2.69,  2.78,  2.49,  2.33,  2.18,  2.03,  2.02,  1.89,
#         1.75,  1.77,  1.69,  1.6 ,  1.55,  1.57,  1.74,  1.93,  1.94,
#         2.12,  2.26,  2.32,  2.38,  2.55,  2.6 ,  2.42,  2.36,  2.81,
#         2.91,  3.31,  3.41,  4.33,  4.18,  4.32,  3.67,  3.54,  3.33,
#         3.08,  2.46,  2.39,  2.47,  2.16,  2.06,  1.87,  1.82,  1.92,
#         1.7 ,  1.8 ,  1.79,  1.81,  1.66,  1.56,  1.53,  1.47,  1.45,
#         1.34,  1.38,  1.23,  1.08,  1.06,  0.93,  0.98,  0.94,  0.99,
#         0.92,  0.95,  1.03,  0.97,  1.07,  1.1 ,  1.22,  1.36,  1.63,
#         1.88,  1.71,  1.97,  2.05,  1.99,  2.4 ,  3.01,  3.3 ,  3.36,
#         3.09,  2.68,  2.72,  2.54,  2.56,  2.73,  2.48,  1.95,  2.09,
#         2.07,  1.67,  1.62,  1.42,  1.41,  1.28,  1.25,  1.17,  1.19,
#         1.3 ,  1.16,  1.09,  1.11,  2.61,  2.9 ,  2.99,  3.05,  2.97,
#         3.6 ,  3.92,  4.39,  3.8 ,  3.72,  3.47,  3.65,  3.87,  3.88,
#         4.21,  4.07,  4.02,  3.64,  3.52,  3.97,  3.98,  3.86,  4.12,
#         3.38,  3.19,  3.43,  3.06,  3.46,  3.24,  3.22,  3.42,  3.69,
#         3.28,  3.12,  3.  ,  3.62,  3.5 ,  4.42,  4.5 ,  5.19,  5.63,
#         5.73,  4.98,  5.23,  6.29,  5.78,  5.62,  6.3 ,  6.6 ,  6.55,
#         6.13,  6.15,  6.05,  5.87,  5.66,  5.85,  5.36,  5.22,  5.96,
#         5.97,  5.39,  5.16,  4.45,  4.05,  3.61,  2.71,  2.51,  2.59,
#         1.83,  1.39,  1.44,  1.32, 99.  ,  1.14,  1.12,  1.37,  1.15,
#         1.86,  2.19,  2.79,  3.07,  3.23,  3.25,  4.03,  4.  ,  3.66,
#         3.73,  2.58,  1.96,  2.37,  2.08,  1.72,  1.59,  1.46,  1.76,
#         1.61,  0.83,  0.87,  0.89,  0.9 ,  2.53,  2.94,  2.98,  3.04,
#         2.84,  2.63,  2.82,  2.5 ,  2.41,  2.  ,  1.78,  2.29,  3.34,
#         3.93,  5.04,  5.75,  6.02,  6.54,  6.03,  6.27,  5.81,  5.69,
#         5.6 ,  6.38,  5.56,  5.7 ,  5.15,  5.32,  5.14,  4.78,  5.03,
#         4.68,  4.86,  4.28,  4.88,  4.52,  4.1 ,  4.25,  3.81,  3.32,
#         3.13,  1.9 ,  1.84,  1.54,  1.21,  2.23,  2.93,  2.88,  3.02,
#         2.89,  2.57,  1.64,  0.88,  0.85,  0.86,  0.84,  0.81,  0.74,
#         0.82,  0.78,  0.79,  0.91,  3.56,  3.63,  2.77,  2.67,  2.24,
#         2.7 ,  1.27,  3.15,  3.2 ,  3.49,  3.21,  2.66,  3.68,  4.41,
#         4.94,  5.11,  5.27,  5.26,  5.68,  5.3 ,  4.27,  5.35,  5.08,
#         4.43,  3.45,  3.14,  2.85,  2.87,  3.11,  3.51,  3.79,  3.48,
#         2.96])

# %%
data = data[data['WVHT'] != 99]

# %%
data.shape
# Out:
# (2155, 2)

# %%
data['WVHT'].plot(figsize=(8,6))
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
data['date_time'] = pd.to_datetime(data['date_time'])
data = data.sort_values(by='date_time')
y = data['WVHT'].values

# %%
# Define a function to prepare sequences
def prepare_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

# %%
# Prepare sequences and targets
sequence_length = 100  # Adjust as needed
x_seq, y_targets = prepare_sequences(y, sequence_length)

# %%
# Split the data into train and test sets
split_ratio = 0.7  # Adjust as needed
split_idx = int(split_ratio * len(x_seq))
x_train, x_test = x_seq[:split_idx], x_seq[split_idx:]
y_train, y_test = y_targets[:split_idx], y_targets[split_idx:]

# %%
# Define quantile loss function using TensorFlow operations
def quantile_loss(q, y_true, y_pred):
    error = y_true - y_pred
    return tf.reduce_mean(tf.maximum(q * error, (q - 1) * error))

# %%
# Import the Dropout layer from TensorFlow
from tensorflow.keras.layers import Dropout

# %%
# Define and train the LSTM model with quantile loss
def train_model_with_quantile_loss(q):
    model = Sequential([
        LSTM(64, activation='sigmoid', input_shape=(sequence_length, 1)),
        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss=lambda y_true, y_pred: quantile_loss(q, y_true, y_pred))
    model.fit(x_train, y_train, validation_split=0.1, epochs=50, batch_size=60, verbose=1)
    return model

# %%
#Train models with 20% and 80% quantiles
q_05 = 0.05  # 10% quantile
model_05 = train_model_with_quantile_loss(q_05)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 4s 100ms/step - loss: 0.0659 - val_loss: 0.0466
# Epoch 2/50
# 22/22 [==============================] - 2s 98ms/step - loss: 0.0562 - val_loss: 0.0416
# Epoch 3/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0519 - val_loss: 0.0388
# Epoch 4/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0484 - val_loss: 0.0355
# Epoch 5/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0444 - val_loss: 0.0412
# Epoch 6/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0394 - val_loss: 0.0286
# Epoch 7/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0332 - val_loss: 0.0228
# Epoch 8/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0269 - val_loss: 0.0189
# Epoch 9/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0231 - val_loss: 0.0157
# Epoch 10/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0217 - val_loss: 0.0182
# Epoch 11/50
# 22/22 [==============================] - 2s 91ms/step - loss: 0.0217 - val_loss: 0.0145
# Epoch 12/50
# 22/22 [==============================] - 2s 93ms/step - loss: 0.0201 - val_loss: 0.0138
# Epoch 13/50
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0192 - val_loss: 0.0136
# Epoch 14/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0186 - val_loss: 0.0149
# Epoch 15/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0182 - val_loss: 0.0134
# Epoch 16/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0183 - val_loss: 0.0134
# Epoch 17/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0173 - val_loss: 0.0130
# Epoch 18/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0180 - val_loss: 0.0126
# Epoch 19/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0168 - val_loss: 0.0136
# Epoch 20/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0194 - val_loss: 0.0125
# Epoch 21/50
# 22/22 [==============================] - 2s 94ms/step - loss: 0.0169 - val_loss: 0.0128
# Epoch 22/50
# 22/22 [==============================] - 2s 92ms/step - loss: 0.0166 - val_loss: 0.0128
# Epoch 23/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0166 - val_loss: 0.0123
# Epoch 24/50
# 22/22 [==============================] - 2s 85ms/step - loss: 0.0163 - val_loss: 0.0122
# Epoch 25/50
# 22/22 [==============================] - 2s 97ms/step - loss: 0.0162 - val_loss: 0.0126
# Epoch 26/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0165 - val_loss: 0.0124
# Epoch 27/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0164 - val_loss: 0.0130
# Epoch 28/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0158 - val_loss: 0.0130
# Epoch 29/50
# 22/22 [==============================] - 1s 64ms/step - loss: 0.0157 - val_loss: 0.0127
# Epoch 30/50
# 22/22 [==============================] - 2s 90ms/step - loss: 0.0159 - val_loss: 0.0142
# Epoch 31/50
# 22/22 [==============================] - 2s 76ms/step - loss: 0.0173 - val_loss: 0.0149
# Epoch 32/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0162 - val_loss: 0.0133
# Epoch 33/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 34/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0176 - val_loss: 0.0136
# Epoch 35/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0160 - val_loss: 0.0125
# Epoch 36/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0155 - val_loss: 0.0133
# Epoch 37/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0156 - val_loss: 0.0126
# Epoch 38/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0154 - val_loss: 0.0128
# Epoch 39/50
# 22/22 [==============================] - 1s 69ms/step - loss: 0.0156 - val_loss: 0.0126
# Epoch 40/50
# 22/22 [==============================] - 2s 88ms/step - loss: 0.0150 - val_loss: 0.0124
# Epoch 41/50
# 22/22 [==============================] - 2s 78ms/step - loss: 0.0153 - val_loss: 0.0124
# Epoch 42/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0150 - val_loss: 0.0124
# Epoch 43/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0154 - val_loss: 0.0128
# Epoch 44/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0150 - val_loss: 0.0124
# Epoch 45/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 46/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0152 - val_loss: 0.0156
# Epoch 47/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0151 - val_loss: 0.0124
# Epoch 48/50
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0151 - val_loss: 0.0127
# Epoch 49/50
# 22/22 [==============================] - 1s 67ms/step - loss: 0.0154 - val_loss: 0.0130
# Epoch 50/50
# 22/22 [==============================] - 2s 91ms/step - loss: 0.0149 - val_loss: 0.0136

# %%
q_95 = 0.95  # 90% quantile
model_95 = train_model_with_quantile_loss(q_95)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 3s 71ms/step - loss: 0.5515 - val_loss: 0.0810
# Epoch 2/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1660 - val_loss: 0.1284
# Epoch 3/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1592 - val_loss: 0.1278
# Epoch 4/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.1546 - val_loss: 0.1158
# Epoch 5/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.1498 - val_loss: 0.1052
# Epoch 6/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.1450 - val_loss: 0.1027
# Epoch 7/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1407 - val_loss: 0.1021
# Epoch 8/50
# 22/22 [==============================] - 2s 90ms/step - loss: 0.1346 - val_loss: 0.0932
# Epoch 9/50
# 22/22 [==============================] - 2s 91ms/step - loss: 0.1299 - val_loss: 0.0940
# Epoch 10/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1245 - val_loss: 0.0910
# Epoch 11/50
# 22/22 [==============================] - 1s 54ms/step - loss: 0.1193 - val_loss: 0.0881
# Epoch 12/50
# 22/22 [==============================] - 1s 54ms/step - loss: 0.1142 - val_loss: 0.0832
# Epoch 13/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.1089 - val_loss: 0.0843
# Epoch 14/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1042 - val_loss: 0.0761
# Epoch 15/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0960 - val_loss: 0.0721
# Epoch 16/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0890 - val_loss: 0.0681
# Epoch 17/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0813 - val_loss: 0.0565
# Epoch 18/50
# 22/22 [==============================] - 2s 86ms/step - loss: 0.0733 - val_loss: 0.0502
# Epoch 19/50
# 22/22 [==============================] - 2s 90ms/step - loss: 0.0644 - val_loss: 0.0490
# Epoch 20/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0549 - val_loss: 0.0407
# Epoch 21/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0460 - val_loss: 0.0326
# Epoch 22/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0386 - val_loss: 0.0290
# Epoch 23/50
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0353 - val_loss: 0.0293
# Epoch 24/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0322 - val_loss: 0.0341
# Epoch 25/50
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0308 - val_loss: 0.0269
# Epoch 26/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0294 - val_loss: 0.0277
# Epoch 27/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0281 - val_loss: 0.0287
# Epoch 28/50
# 22/22 [==============================] - 2s 87ms/step - loss: 0.0282 - val_loss: 0.0257
# Epoch 29/50
# 22/22 [==============================] - 2s 90ms/step - loss: 0.0289 - val_loss: 0.0290
# Epoch 30/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0274 - val_loss: 0.0241
# Epoch 31/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0267 - val_loss: 0.0237
# Epoch 32/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0257 - val_loss: 0.0260
# Epoch 33/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0258 - val_loss: 0.0231
# Epoch 34/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0251 - val_loss: 0.0226
# Epoch 35/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0240 - val_loss: 0.0228
# Epoch 36/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0245 - val_loss: 0.0221
# Epoch 37/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0243 - val_loss: 0.0221
# Epoch 38/50
# 22/22 [==============================] - 2s 85ms/step - loss: 0.0233 - val_loss: 0.0218
# Epoch 39/50
# 22/22 [==============================] - 2s 97ms/step - loss: 0.0224 - val_loss: 0.0217
# Epoch 40/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0232 - val_loss: 0.0212
# Epoch 41/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0224 - val_loss: 0.0228
# Epoch 42/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0229 - val_loss: 0.0214
# Epoch 43/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0245 - val_loss: 0.0205
# Epoch 44/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0245 - val_loss: 0.0248
# Epoch 45/50
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0218 - val_loss: 0.0220
# Epoch 46/50
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0219 - val_loss: 0.0209
# Epoch 47/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0226 - val_loss: 0.0207
# Epoch 48/50
# 22/22 [==============================] - 2s 86ms/step - loss: 0.0214 - val_loss: 0.0210
# Epoch 49/50
# 22/22 [==============================] - 2s 95ms/step - loss: 0.0218 - val_loss: 0.0198
# Epoch 50/50
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0218 - val_loss: 0.0199

# %%
# Make predictions
y_pred_05 = model_05.predict(x_test)
y_pred_95 = model_95.predict(x_test)
# Out:
# 20/20 [==============================] - 1s 19ms/step
# 20/20 [==============================] - 1s 18ms/step

# %%
# Plot quantile predictions along with actual values
plt.plot(range(len(y_test)), y_test, label="Actual")
plt.plot(range(len(y_test)), y_pred_05, label="5% Prediction")
plt.plot(range(len(y_test)), y_pred_95, label="95% Prediction")
plt.xlabel("Data Points in Test Set")
plt.ylabel("WVHT")
plt.legend()
plt.savefig('41002h2022.png')
plt.show()

# Calculate the number of points between 95% and 5% percentiles
num_points_between_percentiles = np.sum((y_pred_05 <= y_test) & (y_test <= y_pred_95))

# %%
# Calculate MPIW
def calculate_mpiw(y_lower, y_upper):
    mpiw = np.mean(y_upper - y_lower)
    return mpiw

# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Calculate MPIW for the 10-90% prediction interval
mpiw = calculate_mpiw(y_lower_05, y_upper_95)

# Print MPIW for the 10-90% prediction interval
print("MPIW:", mpiw)
# Out:
# MPIW: 0.5146685

# %%
print(len(y_test))
# Out:
# 617

# %%
# Check if each actual observation falls within the prediction interval
within_interval = (y_pred_05.flatten() <= y_test) & (y_test <= y_pred_95.flatten())
print(within_interval.sum())
# Out:
# 558

# %%
# Calculate lower and upper bounds of prediction intervals
y_lower_05 = y_pred_05
y_upper_95 = y_pred_95

# Check if each actual observation falls within the prediction interval
within_interval = (y_lower_05.flatten() <= y_test) & (y_test <= y_upper_95.flatten())

# Count the number of observations falling within the prediction intervals
num_within_interval = within_interval.sum()

# Total number of observations
total_observations = len(y_test)

# Calculate PICP (Prediction Interval Coverage Probability)
picp = num_within_interval / total_observations
print("PICP:", picp)
# Out:
# PICP: 0.9043760129659644
